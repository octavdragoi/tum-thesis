# %%
import os
if "ntbk" in os.getcwd():
    os.chdir("..")
print(os.getcwd())

import sys
sys.path.append(os.path.join(os.getcwd(), "otgnn"))


# %load_ext autoreload
# %autoreload 2

from otgnn.models import GCN
from otgnn.graph import MolGraph
from otgnn.utils import save_model, load_model

from mol_opt.mol_opt import MolOpt
from mol_opt.data_mol_opt import MolOptDataset
from mol_opt.data_mol_opt import get_loader
from mol_opt.arguments import get_args
from mol_opt.train_mol_opt import main, get_latest_model
from mol_opt.ot_utils import compute_barycenter
from mol_opt.log_mol_opt import format_data_name, load_data, save_data
from mol_opt.task_metrics import measure_task
from otgnn.utils import save_model, load_model, StatsTracker, log_tensorboard
from molgen.metrics.mol_metrics import MolMetrics
from tensorboardX import SummaryWriter
from mol_opt.log_mol_opt import do_epoch, main
from otgnn.graph import SYMBOLS, FORMAL_CHARGES, BOND_TYPES
from pathlib import Path

from rdkit.Chem import MolFromSmiles

import numpy as np
import time
import torch.nn.functional as F
# Out:
# /home/octav/gitrepos/tum-thesis

# %%
model_type = "transformer-ae"
sys.argv = ["", "-model_type", model_type, "-one_batch_train"]
args = get_args()
outdir_suffix = "dev3"
args.init_model = "{}-test2".format(model_type)
args.output_dir = "mol_opt/output_{}/{}".format(outdir_suffix, args.init_model)
args.tb_logs_dir = "mol_opt/logs_{}/{}".format(outdir_suffix, args.init_model)

print (args.output_dir)
print (args.tb_logs_dir)
# Out:
# mol_opt/output_dev3/transformer-ae-test2
# mol_opt/logs_dev3/transformer-ae-test2

# %%
main(args.output_dir, args.tb_logs_dir,1,  flush_secs = 30, device = 'cpu')
# Out:
# Epoch 1
# Epoch 10
# Epoch 100
# Epoch 101
# Epoch 102
# Epoch 103
# Epoch 104
# Epoch 105
# Epoch 106
# Epoch 107
# Epoch 108
# Epoch 109
# Epoch 110
# Epoch 111
# Epoch 112
# Epoch 113
# Epoch 114
# Epoch 115
# Epoch 116
# Epoch 117
# Epoch 118
# Epoch 119
# Epoch 120
# Epoch 121
# Epoch 122
# Epoch 123
# Epoch 124
# Epoch 125
# Epoch 126
# Epoch 127
# Epoch 128
# Epoch 129
# Epoch 130
# Epoch 131
# Epoch 132
# Epoch 133
# Epoch 134
# Epoch 135
# Epoch 136
# Epoch 137
# Epoch 138
# Epoch 139
# Epoch 140
# Epoch 141
# Epoch 142
# train_0.out
# Losses Epoch 142, train
#  fgw:0.5674895
#  conn_penalty:0.0000000
#  val_penalty:0.0000000
#  euler_penalty:0.0000000
#  total:0.5674895
# Measure Epoch 142, train
#  similarity:0.0005405
#  penlog:1.4027649
# Metrics Epoch 142, train
#  batch_molecular_validity:0.0000000
#  batch_correctness:0.0000000
#  batch_symbol_accuracy:85.4327335
#  batch_molecular_disconnected_validity:100.0000000
#  batch_connected_components:23.3400000
#  batch_invalid_valency_nodes:100.0000000
#  batch_nodes_0degree:23.3400000
#  batch_nodes_7plus_degree:0.0000000
#  invalid_euler_toofew:100.0000000
#  invalid_euler_toomany:0.0000000
#  avg_euler_error:-23.3400000
#  batch_node_degree:0.0000000
# Epoch 143
# train_0.out
# Losses Epoch 143, train
#  fgw:0.5656848
#  conn_penalty:0.0000000
#  val_penalty:0.0000000
#  euler_penalty:0.0000000
#  total:0.5656848
# Measure Epoch 143, train
#  similarity:0.0005405
#  penlog:1.1834878
# Metrics Epoch 143, train
#  batch_molecular_validity:0.0000000
#  batch_correctness:0.0000000
#  batch_symbol_accuracy:85.9468723
#  batch_molecular_disconnected_validity:100.0000000
#  batch_connected_components:23.3400000
#  batch_invalid_valency_nodes:100.0000000
#  batch_nodes_0degree:23.3400000
#  batch_nodes_7plus_degree:0.0000000
#  invalid_euler_toofew:100.0000000
#  invalid_euler_toomany:0.0000000
#  avg_euler_error:-23.3400000
#  batch_node_degree:0.0000000
# Epoch 144
# train_0.out
# Losses Epoch 144, train
#  fgw:0.5693298
#  conn_penalty:0.0000000
#  val_penalty:0.0000000
#  euler_penalty:0.0000000
#  total:0.5693298
# Measure Epoch 144, train
#  similarity:0.0005405
#  penlog:1.4795871
# Metrics Epoch 144, train
#  batch_molecular_validity:0.0000000
#  batch_correctness:0.0000000
#  batch_symbol_accuracy:85.9468723
#  batch_molecular_disconnected_validity:100.0000000
#  batch_connected_components:23.3400000
#  batch_invalid_valency_nodes:100.0000000
#  batch_nodes_0degree:23.3400000
#  batch_nodes_7plus_degree:0.0000000
#  invalid_euler_toofew:100.0000000
#  invalid_euler_toomany:0.0000000
#  avg_euler_error:-23.3400000
#  batch_node_degree:0.0000000
# Epoch 145
# train_0.out
# Losses Epoch 145, train
#  fgw:0.5649524
#  conn_penalty:0.0000000
#  val_penalty:0.0000000
#  euler_penalty:0.0000000
#  total:0.5649524
# Measure Epoch 145, train
#  similarity:0.0010669
#  penlog:1.2731878
# Metrics Epoch 145, train
#  batch_molecular_validity:0.0000000
#  batch_correctness:0.0000000
#  batch_symbol_accuracy:85.9468723
#  batch_molecular_disconnected_validity:100.0000000
#  batch_connected_components:23.3400000
#  batch_invalid_valency_nodes:100.0000000
#  batch_nodes_0degree:23.3400000
#  batch_nodes_7plus_degree:0.0000000
#  invalid_euler_toofew:100.0000000
#  invalid_euler_toomany:0.0000000
#  avg_euler_error:-23.3400000
#  batch_node_degree:0.0000000
# Epoch 146
# train_0.out
# Losses Epoch 146, train
#  fgw:0.5705745
#  conn_penalty:0.0000000
#  val_penalty:0.0000000
#  euler_penalty:0.0000000
#  total:0.5705745
# Measure Epoch 146, train
#  similarity:0.0010391
#  penlog:1.3508532
# Metrics Epoch 146, train
#  batch_molecular_validity:0.0000000
#  batch_correctness:0.0000000
#  batch_symbol_accuracy:86.8894602
#  batch_molecular_disconnected_validity:100.0000000
#  batch_connected_components:23.3400000
#  batch_invalid_valency_nodes:100.0000000
#  batch_nodes_0degree:23.3400000
#  batch_nodes_7plus_degree:0.0000000
#  invalid_euler_toofew:100.0000000
#  invalid_euler_toomany:0.0000000
#  avg_euler_error:-23.3400000
#  batch_node_degree:0.0000000
# Epoch 147
# train_0.out
# Losses Epoch 147, train
#  fgw:0.5690785
#  conn_penalty:0.0000000
#  val_penalty:0.0000000
#  euler_penalty:0.0000000
#  total:0.5690785
# Measure Epoch 147, train
#  similarity:0.0010526
#  penlog:1.0226844
# Metrics Epoch 147, train
#  batch_molecular_validity:0.0000000
#  batch_correctness:0.0000000
#  batch_symbol_accuracy:86.4610111
#  batch_molecular_disconnected_validity:100.0000000
#  batch_connected_components:23.3400000
#  batch_invalid_valency_nodes:100.0000000
#  batch_nodes_0degree:23.3400000
#  batch_nodes_7plus_degree:0.0000000
#  invalid_euler_toofew:100.0000000
#  invalid_euler_toomany:0.0000000
#  avg_euler_error:-23.3400000
#  batch_node_degree:0.0000000
# Currently at epoch 147. Sleeping...
# Epoch 147
# Epoch 148
# train_0.out
# Losses Epoch 148, train
#  fgw:0.5596362
#  conn_penalty:0.0000000
#  val_penalty:0.0000000
#  euler_penalty:0.0000000
#  total:0.5596362
# Measure Epoch 148, train
#  similarity:0.0015932
#  penlog:0.3338676
# Metrics Epoch 148, train
#  batch_molecular_validity:0.0000000
#  batch_correctness:0.0000000
#  batch_symbol_accuracy:86.1182519
#  batch_molecular_disconnected_validity:100.0000000
#  batch_connected_components:23.3400000
#  batch_invalid_valency_nodes:100.0000000
#  batch_nodes_0degree:23.3400000
#  batch_nodes_7plus_degree:0.0000000
#  invalid_euler_toofew:100.0000000
#  invalid_euler_toomany:0.0000000
#  avg_euler_error:-23.3400000
#  batch_node_degree:0.0000000
# Epoch 149
# train_0.out
# Losses Epoch 149, train
#  fgw:0.5606841
#  conn_penalty:0.0000000
#  val_penalty:0.0000000
#  euler_penalty:0.0000000
#  total:0.5606841
# Measure Epoch 149, train
#  similarity:0.0005263
#  penlog:0.8074905
# Metrics Epoch 149, train
#  batch_molecular_validity:0.0000000
#  batch_correctness:0.0000000
#  batch_symbol_accuracy:85.7754927
#  batch_molecular_disconnected_validity:100.0000000
#  batch_connected_components:23.3400000
#  batch_invalid_valency_nodes:100.0000000
#  batch_nodes_0degree:23.3400000
#  batch_nodes_7plus_degree:0.0000000
#  invalid_euler_toofew:100.0000000
#  invalid_euler_toomany:0.0000000
#  avg_euler_error:-23.3400000
#  batch_node_degree:0.0000000
# Epoch 150
# train_0.out
# Losses Epoch 150, train
#  fgw:0.5605490
#  conn_penalty:0.0000000
#  val_penalty:0.0000000
#  euler_penalty:0.0000000
#  total:0.5605490
# Measure Epoch 150, train
#  similarity:0.0010669
#  penlog:1.0099850
# Metrics Epoch 150, train
#  batch_molecular_validity:0.0000000
#  batch_correctness:0.0000000
#  batch_symbol_accuracy:85.7754927
#  batch_molecular_disconnected_validity:100.0000000
#  batch_connected_components:23.3400000
#  batch_invalid_valency_nodes:100.0000000
#  batch_nodes_0degree:23.3400000
#  batch_nodes_7plus_degree:0.0000000
#  invalid_euler_toofew:100.0000000
#  invalid_euler_toomany:0.0000000
#  avg_euler_error:-23.3400000
#  batch_node_degree:0.0000000
# Epoch 151
# train_0.out
# Losses Epoch 151, train
#  fgw:0.5520607
#  conn_penalty:0.0000000
#  val_penalty:0.0000000
#  euler_penalty:0.0000000
#  total:0.5520607
# Measure Epoch 151, train
#  similarity:0.0010669
#  penlog:1.1962518
# Metrics Epoch 151, train
#  batch_molecular_validity:0.0000000
#  batch_correctness:0.0000000
#  batch_symbol_accuracy:86.2896315
#  batch_molecular_disconnected_validity:100.0000000
#  batch_connected_components:23.3400000
#  batch_invalid_valency_nodes:100.0000000
#  batch_nodes_0degree:23.3400000
#  batch_nodes_7plus_degree:0.0000000
#  invalid_euler_toofew:100.0000000
#  invalid_euler_toomany:0.0000000
#  avg_euler_error:-23.3400000
#  batch_node_degree:0.0000000
# Epoch 152
# train_0.out
# Losses Epoch 152, train
#  fgw:0.5579411
#  conn_penalty:0.0000000
#  val_penalty:0.0000000
#  euler_penalty:0.0000000
#  total:0.5579411
# Measure Epoch 152, train
#  similarity:0.0010669
#  penlog:1.2916686
# Metrics Epoch 152, train
#  batch_molecular_validity:0.0000000
#  batch_correctness:0.0000000
#  batch_symbol_accuracy:86.2896315
#  batch_molecular_disconnected_validity:100.0000000
#  batch_connected_components:23.3400000
#  batch_invalid_valency_nodes:100.0000000
#  batch_nodes_0degree:23.3400000
#  batch_nodes_7plus_degree:0.0000000
#  invalid_euler_toofew:100.0000000
#  invalid_euler_toomany:0.0000000
#  avg_euler_error:-23.3400000
#  batch_node_degree:0.0000000
# Epoch 153
# train_0.out
# Losses Epoch 153, train
#  fgw:0.5642110
#  conn_penalty:0.0000000
#  val_penalty:0.0000000
#  euler_penalty:0.0000000
#  total:0.5642110
# Measure Epoch 153, train
#  similarity:0.0010526
#  penlog:1.4623646
# Metrics Epoch 153, train
#  batch_molecular_validity:0.0000000
#  batch_correctness:0.0000000
#  batch_symbol_accuracy:85.6898029
#  batch_molecular_disconnected_validity:100.0000000
#  batch_connected_components:23.3000000
#  batch_invalid_valency_nodes:99.7429306
#  batch_nodes_0degree:23.2800000
#  batch_nodes_7plus_degree:0.0000000
#  invalid_euler_toofew:100.0000000
#  invalid_euler_toomany:0.0000000
#  avg_euler_error:-23.3000000
#  batch_node_degree:0.0068552
# Epoch 154
# Currently at epoch 154. Sleeping...
# Epoch 154
# train_0.out
# Losses Epoch 154, train
#  fgw:0.5542606
#  conn_penalty:0.0000000
#  val_penalty:0.0000000
#  euler_penalty:0.0000000
#  total:0.5542606
# Measure Epoch 154, train
#  similarity:0.0005263
#  penlog:1.3141036
# Metrics Epoch 154, train
#  batch_molecular_validity:0.0000000
#  batch_correctness:0.0000000
#  batch_symbol_accuracy:86.8037704
#  batch_molecular_disconnected_validity:100.0000000
#  batch_connected_components:23.3400000
#  batch_invalid_valency_nodes:100.0000000
#  batch_nodes_0degree:23.3400000
#  batch_nodes_7plus_degree:0.0000000
#  invalid_euler_toofew:100.0000000
#  invalid_euler_toomany:0.0000000
#  avg_euler_error:-23.3400000
#  batch_node_degree:0.0000000
# Epoch 155
# train_0.out
# Losses Epoch 155, train
#  fgw:0.5487367
#  conn_penalty:0.0000000
#  val_penalty:0.0000000
#  euler_penalty:0.0000000
#  total:0.5487367
# Measure Epoch 155, train
#  similarity:0.0015655
#  penlog:1.0310154
# Metrics Epoch 155, train
#  batch_molecular_validity:0.0000000
#  batch_correctness:0.0000000
#  batch_symbol_accuracy:86.5467009
#  batch_molecular_disconnected_validity:100.0000000
#  batch_connected_components:23.3400000
#  batch_invalid_valency_nodes:100.0000000
#  batch_nodes_0degree:23.3400000
#  batch_nodes_7plus_degree:0.0000000
#  invalid_euler_toofew:100.0000000
#  invalid_euler_toomany:0.0000000
#  avg_euler_error:-23.3400000
#  batch_node_degree:0.0000000
# Epoch 156
# train_0.out
# Losses Epoch 156, train
#  fgw:0.5471058
#  conn_penalty:0.0000000
#  val_penalty:0.0000000
#  euler_penalty:0.0000000
#  total:0.5471058
# Measure Epoch 156, train
#  similarity:0.0015789
#  penlog:1.0657386
# Metrics Epoch 156, train
#  batch_molecular_validity:0.0000000
#  batch_correctness:0.0000000
#  batch_symbol_accuracy:86.9751500
#  batch_molecular_disconnected_validity:100.0000000
#  batch_connected_components:23.3400000
#  batch_invalid_valency_nodes:100.0000000
#  batch_nodes_0degree:23.3400000
#  batch_nodes_7plus_degree:0.0000000
#  invalid_euler_toofew:100.0000000
#  invalid_euler_toomany:0.0000000
#  avg_euler_error:-23.3400000
#  batch_node_degree:0.0000000
# Epoch 157
# train_0.out
# Losses Epoch 157, train
#  fgw:0.5425985
#  conn_penalty:0.0000000
#  val_penalty:0.0000000
#  euler_penalty:0.0000000
#  total:0.5425985
# Measure Epoch 157, train
#  similarity:0.0005405
#  penlog:1.1632137
# Metrics Epoch 157, train
#  batch_molecular_validity:0.0000000
#  batch_correctness:0.0000000
#  batch_symbol_accuracy:86.5467009
#  batch_molecular_disconnected_validity:100.0000000
#  batch_connected_components:23.3400000
#  batch_invalid_valency_nodes:100.0000000
#  batch_nodes_0degree:23.3400000
#  batch_nodes_7plus_degree:0.0000000
#  invalid_euler_toofew:100.0000000
#  invalid_euler_toomany:0.0000000
#  avg_euler_error:-23.3400000
#  batch_node_degree:0.0000000
# Epoch 158
# train_0.out
# Losses Epoch 158, train
#  fgw:0.5374356
#  conn_penalty:0.0000000
#  val_penalty:0.0000000
#  euler_penalty:0.0000000
#  total:0.5374356
# Measure Epoch 158, train
#  similarity:0.0010669
#  penlog:1.5329806
# Metrics Epoch 158, train
#  batch_molecular_validity:0.0000000
#  batch_correctness:0.0000000
#  batch_symbol_accuracy:87.1465296
#  batch_molecular_disconnected_validity:100.0000000
#  batch_connected_components:23.3400000
#  batch_invalid_valency_nodes:100.0000000
#  batch_nodes_0degree:23.3400000
#  batch_nodes_7plus_degree:0.0000000
#  invalid_euler_toofew:100.0000000
#  invalid_euler_toomany:0.0000000
#  avg_euler_error:-23.3400000
#  batch_node_degree:0.0000000
# Epoch 159
# train_0.out
# Losses Epoch 159, train
#  fgw:0.5418917
#  conn_penalty:0.0000000
#  val_penalty:0.0000000
#  euler_penalty:0.0000000
#  total:0.5418917
# Measure Epoch 159, train
#  similarity:0.0005405
#  penlog:1.7477686
# Metrics Epoch 159, train
#  batch_molecular_validity:0.0000000
#  batch_correctness:0.0000000
#  batch_symbol_accuracy:86.1182519
#  batch_molecular_disconnected_validity:100.0000000
#  batch_connected_components:23.3400000
#  batch_invalid_valency_nodes:100.0000000
#  batch_nodes_0degree:23.3400000
#  batch_nodes_7plus_degree:0.0000000
#  invalid_euler_toofew:100.0000000
#  invalid_euler_toomany:0.0000000
#  avg_euler_error:-23.3400000
#  batch_node_degree:0.0000000
# Epoch 160
# Currently at epoch 160. Sleeping...
# Epoch 160
# train_0.out
# Losses Epoch 160, train
#  fgw:0.5424717
#  conn_penalty:0.0000000
#  val_penalty:0.0000000
#  euler_penalty:0.0000000
#  total:0.5424717
# Measure Epoch 160, train
#  similarity:0.0005405
#  penlog:1.7885905
# Metrics Epoch 160, train
#  batch_molecular_validity:0.0000000
#  batch_correctness:0.0000000
#  batch_symbol_accuracy:86.5467009
#  batch_molecular_disconnected_validity:100.0000000
#  batch_connected_components:23.3400000
#  batch_invalid_valency_nodes:100.0000000
#  batch_nodes_0degree:23.3400000
#  batch_nodes_7plus_degree:0.0000000
#  invalid_euler_toofew:100.0000000
#  invalid_euler_toomany:0.0000000
#  avg_euler_error:-23.3400000
#  batch_node_degree:0.0000000
# Epoch 161
# train_0.out
# Losses Epoch 161, train
#  fgw:0.5518521
#  conn_penalty:0.0000000
#  val_penalty:0.0000000
#  euler_penalty:0.0000000
#  total:0.5518521
# Measure Epoch 161, train
#  similarity:0.0005405
#  penlog:1.7910882
# Metrics Epoch 161, train
#  batch_molecular_validity:0.0000000
#  batch_correctness:0.0000000
#  batch_symbol_accuracy:86.9751500
#  batch_molecular_disconnected_validity:100.0000000
#  batch_connected_components:23.3400000
#  batch_invalid_valency_nodes:100.0000000
#  batch_nodes_0degree:23.3400000
#  batch_nodes_7plus_degree:0.0000000
#  invalid_euler_toofew:100.0000000
#  invalid_euler_toomany:0.0000000
#  avg_euler_error:-23.3400000
#  batch_node_degree:0.0000000
# Epoch 162
# train_0.out
# Losses Epoch 162, train
#  fgw:0.5442463
#  conn_penalty:0.0000000
#  val_penalty:0.0000000
#  euler_penalty:0.0000000
#  total:0.5442463
# Measure Epoch 162, train
#  similarity:0.0015789
#  penlog:1.3538308
# Metrics Epoch 162, train
#  batch_molecular_validity:0.0000000
#  batch_correctness:0.0000000
#  batch_symbol_accuracy:86.6323907
#  batch_molecular_disconnected_validity:100.0000000
#  batch_connected_components:23.3400000
#  batch_invalid_valency_nodes:100.0000000
#  batch_nodes_0degree:23.3400000
#  batch_nodes_7plus_degree:0.0000000
#  invalid_euler_toofew:100.0000000
#  invalid_euler_toomany:0.0000000
#  avg_euler_error:-23.3400000
#  batch_node_degree:0.0000000
# Epoch 163
# train_0.out
# Losses Epoch 163, train
#  fgw:0.5402896
#  conn_penalty:0.0000000
#  val_penalty:0.0000000
#  euler_penalty:0.0000000
#  total:0.5402896
# Measure Epoch 163, train
#  similarity:0.0015789
#  penlog:0.9580886
# Metrics Epoch 163, train
#  batch_molecular_validity:0.0000000
#  batch_correctness:0.0000000
#  batch_symbol_accuracy:87.2322194
#  batch_molecular_disconnected_validity:100.0000000
#  batch_connected_components:23.3200000
#  batch_invalid_valency_nodes:99.8286204
#  batch_nodes_0degree:23.3000000
#  batch_nodes_7plus_degree:0.0000000
#  invalid_euler_toofew:100.0000000
#  invalid_euler_toomany:0.0000000
#  avg_euler_error:-23.3200000
#  batch_node_degree:0.0034276
# Epoch 164
# train_0.out
# Losses Epoch 164, train
#  fgw:0.5546777
#  conn_penalty:0.0000000
#  val_penalty:0.0000000
#  euler_penalty:0.0000000
#  total:0.5546777
# Measure Epoch 164, train
#  similarity:0.0015789
#  penlog:0.9608920
# Metrics Epoch 164, train
#  batch_molecular_validity:0.0000000
#  batch_correctness:0.0000000
#  batch_symbol_accuracy:86.7180805
#  batch_molecular_disconnected_validity:100.0000000
#  batch_connected_components:23.3400000
#  batch_invalid_valency_nodes:100.0000000
#  batch_nodes_0degree:23.3400000
#  batch_nodes_7plus_degree:0.0000000
#  invalid_euler_toofew:100.0000000
#  invalid_euler_toomany:0.0000000
#  avg_euler_error:-23.3400000
#  batch_node_degree:0.0000000
# Epoch 165
# train_0.out
# Losses Epoch 165, train
#  fgw:0.5359475
#  conn_penalty:0.0000000
#  val_penalty:0.0000000
#  euler_penalty:0.0000000
#  total:0.5359475
# Measure Epoch 165, train
#  similarity:0.0015932
#  penlog:1.2293747
# Metrics Epoch 165, train
#  batch_molecular_validity:0.0000000
#  batch_correctness:0.0000000
#  batch_symbol_accuracy:87.0608398
#  batch_molecular_disconnected_validity:100.0000000
#  batch_connected_components:23.3400000
#  batch_invalid_valency_nodes:100.0000000
#  batch_nodes_0degree:23.3400000
#  batch_nodes_7plus_degree:0.0000000
#  invalid_euler_toofew:100.0000000
#  invalid_euler_toomany:0.0000000
#  avg_euler_error:-23.3400000
#  batch_node_degree:0.0000000
# Epoch 166
# Currently at epoch 166. Sleeping...
# Epoch 166
# train_0.out
# Losses Epoch 166, train
#  fgw:0.5401221
#  conn_penalty:0.0000000
#  val_penalty:0.0000000
#  euler_penalty:0.0000000
#  total:0.5401221
# Measure Epoch 166, train
#  similarity:0.0010669
#  penlog:1.8125254
# Metrics Epoch 166, train
#  batch_molecular_validity:0.0000000
#  batch_correctness:0.0000000
#  batch_symbol_accuracy:86.2039417
#  batch_molecular_disconnected_validity:100.0000000
#  batch_connected_components:23.3200000
#  batch_invalid_valency_nodes:99.8286204
#  batch_nodes_0degree:23.3000000
#  batch_nodes_7plus_degree:0.0000000
#  invalid_euler_toofew:100.0000000
#  invalid_euler_toomany:0.0000000
#  avg_euler_error:-23.3200000
#  batch_node_degree:0.0034276
# Epoch 167
# train_0.out
# Losses Epoch 167, train
#  fgw:0.5330852
#  conn_penalty:0.0000000
#  val_penalty:0.0000000
#  euler_penalty:0.0000000
#  total:0.5330852
# Measure Epoch 167, train
#  similarity:0.0005405
#  penlog:1.4801127
# Metrics Epoch 167, train
#  batch_molecular_validity:0.0000000
#  batch_correctness:0.0000000
#  batch_symbol_accuracy:87.4035990
#  batch_molecular_disconnected_validity:100.0000000
#  batch_connected_components:23.3200000
#  batch_invalid_valency_nodes:99.8286204
#  batch_nodes_0degree:23.3000000
#  batch_nodes_7plus_degree:0.0000000
#  invalid_euler_toofew:100.0000000
#  invalid_euler_toomany:0.0000000
#  avg_euler_error:-23.3200000
#  batch_node_degree:0.0034276
# Epoch 168
# train_0.out
# Losses Epoch 168, train
#  fgw:0.5323777
#  conn_penalty:0.0000000
#  val_penalty:0.0000000
#  euler_penalty:0.0000000
#  total:0.5323777
# Measure Epoch 168, train
#  similarity:0.0005405
#  penlog:1.6345657
# Metrics Epoch 168, train
#  batch_molecular_validity:0.0000000
#  batch_correctness:0.0000000
#  batch_symbol_accuracy:86.2896315
#  batch_molecular_disconnected_validity:100.0000000
#  batch_connected_components:23.3400000
#  batch_invalid_valency_nodes:100.0000000
#  batch_nodes_0degree:23.3400000
#  batch_nodes_7plus_degree:0.0000000
#  invalid_euler_toofew:100.0000000
#  invalid_euler_toomany:0.0000000
#  avg_euler_error:-23.3400000
#  batch_node_degree:0.0000000
# Epoch 169
# train_0.out
# Losses Epoch 169, train
#  fgw:0.5441509
#  conn_penalty:0.0000000
#  val_penalty:0.0000000
#  euler_penalty:0.0000000
#  total:0.5441509
# Measure Epoch 169, train
#  similarity:0.0015789
#  penlog:1.0386652
# Metrics Epoch 169, train
#  batch_molecular_validity:0.0000000
#  batch_correctness:0.0000000
#  batch_symbol_accuracy:87.6606684
#  batch_molecular_disconnected_validity:100.0000000
#  batch_connected_components:23.3200000
#  batch_invalid_valency_nodes:99.8286204
#  batch_nodes_0degree:23.3000000
#  batch_nodes_7plus_degree:0.0000000
#  invalid_euler_toofew:100.0000000
#  invalid_euler_toomany:0.0000000
#  avg_euler_error:-23.3200000
#  batch_node_degree:0.0034276
# Epoch 170
# train_0.out
# Losses Epoch 170, train
#  fgw:0.5506973
#  conn_penalty:0.0000000
#  val_penalty:0.0000000
#  euler_penalty:0.0000000
#  total:0.5506973
# Measure Epoch 170, train
#  similarity:0.0015655
#  penlog:0.1345982
# Metrics Epoch 170, train
#  batch_molecular_validity:0.0000000
#  batch_correctness:0.0000000
#  batch_symbol_accuracy:86.5467009
#  batch_molecular_disconnected_validity:100.0000000
#  batch_connected_components:23.3000000
#  batch_invalid_valency_nodes:99.6572408
#  batch_nodes_0degree:23.2600000
#  batch_nodes_7plus_degree:0.0000000
#  invalid_euler_toofew:100.0000000
#  invalid_euler_toomany:0.0000000
#  avg_euler_error:-23.3000000
#  batch_node_degree:0.0051414
# Epoch 171
# train_0.out
# Losses Epoch 171, train
#  fgw:0.6131913
#  conn_penalty:0.0000000
#  val_penalty:0.0000000
#  euler_penalty:0.0000000
#  total:0.6131913
# Measure Epoch 171, train
#  similarity:0.0015932
#  penlog:1.4040297
# Metrics Epoch 171, train
#  batch_molecular_validity:0.0000000
#  batch_correctness:0.0000000
#  batch_symbol_accuracy:85.0042845
#  batch_molecular_disconnected_validity:100.0000000
#  batch_connected_components:23.3200000
#  batch_invalid_valency_nodes:99.8286204
#  batch_nodes_0degree:23.3000000
#  batch_nodes_7plus_degree:0.0000000
#  invalid_euler_toofew:100.0000000
#  invalid_euler_toomany:0.0000000
#  avg_euler_error:-23.3200000
#  batch_node_degree:0.0034276
# Epoch 172
# Currently at epoch 172. Sleeping...
# Epoch 172
# train_0.out
# Losses Epoch 172, train
#  fgw:0.5574841
#  conn_penalty:0.0000000
#  val_penalty:0.0000000
#  euler_penalty:0.0000000
#  total:0.5574841
# Measure Epoch 172, train
#  similarity:0.0015789
#  penlog:0.5195105
# Metrics Epoch 172, train
#  batch_molecular_validity:0.0000000
#  batch_correctness:0.0000000
#  batch_symbol_accuracy:86.0325621
#  batch_molecular_disconnected_validity:100.0000000
#  batch_connected_components:23.3000000
#  batch_invalid_valency_nodes:99.7429306
#  batch_nodes_0degree:23.2800000
#  batch_nodes_7plus_degree:0.0000000
#  invalid_euler_toofew:100.0000000
#  invalid_euler_toomany:0.0000000
#  avg_euler_error:-23.3000000
#  batch_node_degree:0.0068552
# Epoch 173
# train_0.out
# Losses Epoch 173, train
#  fgw:0.5443460
#  conn_penalty:0.0000000
#  val_penalty:0.0000000
#  euler_penalty:0.0000000
#  total:0.5443460
# Measure Epoch 173, train
#  similarity:0.0015789
#  penlog:0.6406540
# Metrics Epoch 173, train
#  batch_molecular_validity:0.0000000
#  batch_correctness:0.0000000
#  batch_symbol_accuracy:86.6323907
#  batch_molecular_disconnected_validity:100.0000000
#  batch_connected_components:23.3400000
#  batch_invalid_valency_nodes:100.0000000
#  batch_nodes_0degree:23.3400000
#  batch_nodes_7plus_degree:0.0000000
#  invalid_euler_toofew:100.0000000
#  invalid_euler_toomany:0.0000000
#  avg_euler_error:-23.3400000
#  batch_node_degree:0.0000000
# Epoch 174
# train_0.out
# Losses Epoch 174, train
#  fgw:0.5879929
#  conn_penalty:0.0000000
#  val_penalty:0.0000000
#  euler_penalty:0.0000000
#  total:0.5879929
# Measure Epoch 174, train
#  similarity:0.0015789
#  penlog:2.5375221
# Metrics Epoch 174, train
#  batch_molecular_validity:0.0000000
#  batch_correctness:0.0000000
#  batch_symbol_accuracy:84.5758355
#  batch_molecular_disconnected_validity:100.0000000
#  batch_connected_components:23.3400000
#  batch_invalid_valency_nodes:100.0000000
#  batch_nodes_0degree:23.3400000
#  batch_nodes_7plus_degree:0.0000000
#  invalid_euler_toofew:100.0000000
#  invalid_euler_toomany:0.0000000
#  avg_euler_error:-23.3400000
#  batch_node_degree:0.0000000
# Epoch 175
# train_0.out
# Losses Epoch 175, train
#  fgw:0.5651209
#  conn_penalty:0.0000000
#  val_penalty:0.0000000
#  euler_penalty:0.0000000
#  total:0.5651209
# Measure Epoch 175, train
#  similarity:0.0015789
#  penlog:2.3630742
# Metrics Epoch 175, train
#  batch_molecular_validity:0.0000000
#  batch_correctness:0.0000000
#  batch_symbol_accuracy:85.0042845
#  batch_molecular_disconnected_validity:100.0000000
#  batch_connected_components:23.3400000
#  batch_invalid_valency_nodes:100.0000000
#  batch_nodes_0degree:23.3400000
#  batch_nodes_7plus_degree:0.0000000
#  invalid_euler_toofew:100.0000000
#  invalid_euler_toomany:0.0000000
#  avg_euler_error:-23.3400000
#  batch_node_degree:0.0000000
# Epoch 176
# train_0.out
# Losses Epoch 176, train
#  fgw:0.5966167
#  conn_penalty:0.0000000
#  val_penalty:0.0000000
#  euler_penalty:0.0000000
#  total:0.5966167
# Measure Epoch 176, train
#  similarity:0.0005405
#  penlog:2.3876936
# Metrics Epoch 176, train
#  batch_molecular_validity:0.0000000
#  batch_correctness:0.0000000
#  batch_symbol_accuracy:82.0051414
#  batch_molecular_disconnected_validity:100.0000000
#  batch_connected_components:23.3400000
#  batch_invalid_valency_nodes:100.0000000
#  batch_nodes_0degree:23.3400000
#  batch_nodes_7plus_degree:0.0000000
#  invalid_euler_toofew:100.0000000
#  invalid_euler_toomany:0.0000000
#  avg_euler_error:-23.3400000
#  batch_node_degree:0.0000000
# Epoch 177
# train_0.out
# Losses Epoch 177, train
#  fgw:0.5473352
#  conn_penalty:0.0000000
#  val_penalty:0.0000000
#  euler_penalty:0.0000000
#  total:0.5473352
# Measure Epoch 177, train
#  similarity:0.0165187
#  penlog:-3.2704651
# Metrics Epoch 177, train
#  batch_molecular_validity:0.0000000
#  batch_correctness:0.0000000
#  batch_symbol_accuracy:86.8037704
#  batch_molecular_disconnected_validity:96.0000000
#  batch_connected_components:21.4200000
#  batch_invalid_valency_nodes:88.8603256
#  batch_nodes_0degree:20.6600000
#  batch_nodes_7plus_degree:0.0200000
#  invalid_euler_toofew:100.0000000
#  invalid_euler_toomany:0.0000000
#  avg_euler_error:-20.8800000
#  batch_node_degree:0.2107969
# Epoch 178
# Currently at epoch 178. Sleeping...
# Epoch 178
# train_0.out
# Losses Epoch 178, train
#  fgw:0.5706825
#  conn_penalty:0.0000000
#  val_penalty:0.0000000
#  euler_penalty:0.0000000
#  total:0.5706825
# Measure Epoch 178, train
#  similarity:0.0015932
#  penlog:0.8379267
# Metrics Epoch 178, train
#  batch_molecular_validity:0.0000000
#  batch_correctness:0.0000000
#  batch_symbol_accuracy:83.8046272
#  batch_molecular_disconnected_validity:100.0000000
#  batch_connected_components:23.3400000
#  batch_invalid_valency_nodes:100.0000000
#  batch_nodes_0degree:23.3400000
#  batch_nodes_7plus_degree:0.0000000
#  invalid_euler_toofew:100.0000000
#  invalid_euler_toomany:0.0000000
#  avg_euler_error:-23.3400000
#  batch_node_degree:0.0000000
# Epoch 179
# train_0.out
# Losses Epoch 179, train
#  fgw:0.5913517
#  conn_penalty:0.0000000
#  val_penalty:0.0000000
#  euler_penalty:0.0000000
#  total:0.5913517
# Measure Epoch 179, train
#  similarity:0.0015789
#  penlog:1.5895421
# Metrics Epoch 179, train
#  batch_molecular_validity:0.0000000
#  batch_correctness:0.0000000
#  batch_symbol_accuracy:83.1191088
#  batch_molecular_disconnected_validity:100.0000000
#  batch_connected_components:23.3200000
#  batch_invalid_valency_nodes:99.8286204
#  batch_nodes_0degree:23.3000000
#  batch_nodes_7plus_degree:0.0000000
#  invalid_euler_toofew:100.0000000
#  invalid_euler_toomany:0.0000000
#  avg_euler_error:-23.3200000
#  batch_node_degree:0.0034276
# Epoch 180
# train_0.out
# Losses Epoch 180, train
#  fgw:0.5573095
#  conn_penalty:0.0000000
#  val_penalty:0.0000000
#  euler_penalty:0.0000000
#  total:0.5573095
# Measure Epoch 180, train
#  similarity:0.0005405
#  penlog:2.3836959
# Metrics Epoch 180, train
#  batch_molecular_validity:0.0000000
#  batch_correctness:0.0000000
#  batch_symbol_accuracy:85.9468723
#  batch_molecular_disconnected_validity:100.0000000
#  batch_connected_components:23.3400000
#  batch_invalid_valency_nodes:100.0000000
#  batch_nodes_0degree:23.3400000
#  batch_nodes_7plus_degree:0.0000000
#  invalid_euler_toofew:100.0000000
#  invalid_euler_toomany:0.0000000
#  avg_euler_error:-23.3400000
#  batch_node_degree:0.0000000
# Epoch 181
# train_0.out
# Losses Epoch 181, train
#  fgw:0.5845234
#  conn_penalty:0.0000000
#  val_penalty:0.0000000
#  euler_penalty:0.0000000
#  total:0.5845234
# Measure Epoch 181, train
#  similarity:0.0005405
#  penlog:2.8735621
# Metrics Epoch 181, train
#  batch_molecular_validity:0.0000000
#  batch_correctness:0.0000000
#  batch_symbol_accuracy:81.4910026
#  batch_molecular_disconnected_validity:100.0000000
#  batch_connected_components:23.2800000
#  batch_invalid_valency_nodes:99.5715510
#  batch_nodes_0degree:23.2400000
#  batch_nodes_7plus_degree:0.0000000
#  invalid_euler_toofew:100.0000000
#  invalid_euler_toomany:0.0000000
#  avg_euler_error:-23.2800000
#  batch_node_degree:0.0102828
# Epoch 182
# train_0.out
# Losses Epoch 182, train
#  fgw:0.5509133
#  conn_penalty:0.0000000
#  val_penalty:0.0000000
#  euler_penalty:0.0000000
#  total:0.5509133
# Measure Epoch 182, train
#  similarity:0.0164972
#  penlog:-1.8792557
# Metrics Epoch 182, train
#  batch_molecular_validity:0.0000000
#  batch_correctness:0.0000000
#  batch_symbol_accuracy:85.8611825
#  batch_molecular_disconnected_validity:96.0000000
#  batch_connected_components:21.0200000
#  batch_invalid_valency_nodes:86.2039417
#  batch_nodes_0degree:20.0600000
#  batch_nodes_7plus_degree:0.0000000
#  invalid_euler_toofew:100.0000000
#  invalid_euler_toomany:0.0000000
#  avg_euler_error:-20.4600000
#  batch_node_degree:0.2519280
# Epoch 183
# train_0.out
# Losses Epoch 183, train
#  fgw:0.5529908
#  conn_penalty:0.0000000
#  val_penalty:0.0000000
#  euler_penalty:0.0000000
#  total:0.5529908
# Measure Epoch 183, train
#  similarity:0.0010669
#  penlog:1.5796089
# Metrics Epoch 183, train
#  batch_molecular_validity:0.0000000
#  batch_correctness:0.0000000
#  batch_symbol_accuracy:85.4327335
#  batch_molecular_disconnected_validity:100.0000000
#  batch_connected_components:23.3400000
#  batch_invalid_valency_nodes:100.0000000
#  batch_nodes_0degree:23.3400000
#  batch_nodes_7plus_degree:0.0000000
#  invalid_euler_toofew:100.0000000
#  invalid_euler_toomany:0.0000000
#  avg_euler_error:-23.3400000
#  batch_node_degree:0.0000000
# Epoch 184
# Currently at epoch 184. Sleeping...
# Epoch 184
# train_0.out
# Losses Epoch 184, train
#  fgw:0.5566997
#  conn_penalty:0.0000000
#  val_penalty:0.0000000
#  euler_penalty:0.0000000
#  total:0.5566997
# Measure Epoch 184, train
#  similarity:0.0015789
#  penlog:1.1012587
# Metrics Epoch 184, train
#  batch_molecular_validity:0.0000000
#  batch_correctness:0.0000000
#  batch_symbol_accuracy:85.2613539
#  batch_molecular_disconnected_validity:100.0000000
#  batch_connected_components:23.3200000
#  batch_invalid_valency_nodes:99.8286204
#  batch_nodes_0degree:23.3000000
#  batch_nodes_7plus_degree:0.0000000
#  invalid_euler_toofew:100.0000000
#  invalid_euler_toomany:0.0000000
#  avg_euler_error:-23.3200000
#  batch_node_degree:0.0034276
# Epoch 185
# train_0.out
# Losses Epoch 185, train
#  fgw:0.5473559
#  conn_penalty:0.0000000
#  val_penalty:0.0000000
#  euler_penalty:0.0000000
#  total:0.5473559
# Measure Epoch 185, train
#  similarity:0.0015789
#  penlog:0.8697045
# Metrics Epoch 185, train
#  batch_molecular_validity:0.0000000
#  batch_correctness:0.0000000
#  batch_symbol_accuracy:87.0608398
#  batch_molecular_disconnected_validity:100.0000000
#  batch_connected_components:23.3400000
#  batch_invalid_valency_nodes:100.0000000
#  batch_nodes_0degree:23.3400000
#  batch_nodes_7plus_degree:0.0000000
#  invalid_euler_toofew:100.0000000
#  invalid_euler_toomany:0.0000000
#  avg_euler_error:-23.3400000
#  batch_node_degree:0.0000000
# Epoch 186
# train_0.out
# Losses Epoch 186, train
#  fgw:0.5524054
#  conn_penalty:0.0000000
#  val_penalty:0.0000000
#  euler_penalty:0.0000000
#  total:0.5524054
# Measure Epoch 186, train
#  similarity:0.0035144
#  penlog:1.5908198
# Metrics Epoch 186, train
#  batch_molecular_validity:0.0000000
#  batch_correctness:0.0000000
#  batch_symbol_accuracy:85.0042845
#  batch_molecular_disconnected_validity:100.0000000
#  batch_connected_components:23.2600000
#  batch_invalid_valency_nodes:99.4001714
#  batch_nodes_0degree:23.2000000
#  batch_nodes_7plus_degree:0.0000000
#  invalid_euler_toofew:100.0000000
#  invalid_euler_toomany:0.0000000
#  avg_euler_error:-23.2600000
#  batch_node_degree:0.0068552
# Epoch 187
# train_0.out
# Losses Epoch 187, train
#  fgw:0.5329741
#  conn_penalty:0.0000000
#  val_penalty:0.0000000
#  euler_penalty:0.0000000
#  total:0.5329741
# Measure Epoch 187, train
#  similarity:0.0063167
#  penlog:2.0226622
# Metrics Epoch 187, train
#  batch_molecular_validity:0.0000000
#  batch_correctness:0.0000000
#  batch_symbol_accuracy:87.4892888
#  batch_molecular_disconnected_validity:100.0000000
#  batch_connected_components:22.9200000
#  batch_invalid_valency_nodes:96.6580977
#  batch_nodes_0degree:22.5600000
#  batch_nodes_7plus_degree:0.0000000
#  invalid_euler_toofew:100.0000000
#  invalid_euler_toomany:0.0000000
#  avg_euler_error:-22.9200000
#  batch_node_degree:0.0359897
# Epoch 188
# train_0.out
# Losses Epoch 188, train
#  fgw:0.5634476
#  conn_penalty:0.0000000
#  val_penalty:0.0000000
#  euler_penalty:0.0000000
#  total:0.5634476
# Measure Epoch 188, train
#  similarity:0.0021814
#  penlog:2.2000381
# Metrics Epoch 188, train
#  batch_molecular_validity:0.0000000
#  batch_correctness:0.0000000
#  batch_symbol_accuracy:85.6041131
#  batch_molecular_disconnected_validity:100.0000000
#  batch_connected_components:23.3000000
#  batch_invalid_valency_nodes:99.6572408
#  batch_nodes_0degree:23.2600000
#  batch_nodes_7plus_degree:0.0000000
#  invalid_euler_toofew:100.0000000
#  invalid_euler_toomany:0.0000000
#  avg_euler_error:-23.3000000
#  batch_node_degree:0.0034276
# Epoch 189
# train_0.out
# Losses Epoch 189, train
#  fgw:0.5365860
#  conn_penalty:0.0000000
#  val_penalty:0.0000000
#  euler_penalty:0.0000000
#  total:0.5365860
# Measure Epoch 189, train
#  similarity:0.0010526
#  penlog:1.4108498
# Metrics Epoch 189, train
#  batch_molecular_validity:0.0000000
#  batch_correctness:0.0000000
#  batch_symbol_accuracy:87.0608398
#  batch_molecular_disconnected_validity:100.0000000
#  batch_connected_components:23.3400000
#  batch_invalid_valency_nodes:100.0000000
#  batch_nodes_0degree:23.3400000
#  batch_nodes_7plus_degree:0.0000000
#  invalid_euler_toofew:100.0000000
#  invalid_euler_toomany:0.0000000
#  avg_euler_error:-23.3400000
#  batch_node_degree:0.0000000
# Epoch 190
# train_0.out
# Losses Epoch 190, train
#  fgw:0.5372004
#  conn_penalty:0.0000000
#  val_penalty:0.0000000
#  euler_penalty:0.0000000
#  total:0.5372004
# Measure Epoch 190, train
#  similarity:0.0015789
#  penlog:1.0358612
# Metrics Epoch 190, train
#  batch_molecular_validity:0.0000000
#  batch_correctness:0.0000000
#  batch_symbol_accuracy:87.4892888
#  batch_molecular_disconnected_validity:100.0000000
#  batch_connected_components:23.3400000
#  batch_invalid_valency_nodes:100.0000000
#  batch_nodes_0degree:23.3400000
#  batch_nodes_7plus_degree:0.0000000
#  invalid_euler_toofew:100.0000000
#  invalid_euler_toomany:0.0000000
#  avg_euler_error:-23.3400000
#  batch_node_degree:0.0000000
# Currently at epoch 190. Sleeping...
# Epoch 190
# Epoch 191
# train_0.out
# Losses Epoch 191, train
#  fgw:0.5461962
#  conn_penalty:0.0000000
#  val_penalty:0.0000000
#  euler_penalty:0.0000000
#  total:0.5461962
# Measure Epoch 191, train
#  similarity:0.0015789
#  penlog:0.9796077
# Metrics Epoch 191, train
#  batch_molecular_validity:0.0000000
#  batch_correctness:0.0000000
#  batch_symbol_accuracy:86.5467009
#  batch_molecular_disconnected_validity:100.0000000
#  batch_connected_components:23.3400000
#  batch_invalid_valency_nodes:100.0000000
#  batch_nodes_0degree:23.3400000
#  batch_nodes_7plus_degree:0.0000000
#  invalid_euler_toofew:100.0000000
#  invalid_euler_toomany:0.0000000
#  avg_euler_error:-23.3400000
#  batch_node_degree:0.0000000
# Epoch 192
# train_0.out
# Losses Epoch 192, train
#  fgw:0.5262494
#  conn_penalty:0.0000000
#  val_penalty:0.0000000
#  euler_penalty:0.0000000
#  total:0.5262494
# Measure Epoch 192, train
#  similarity:0.0079200
#  penlog:0.8408623
# Metrics Epoch 192, train
#  batch_molecular_validity:0.0000000
#  batch_correctness:0.0000000
#  batch_symbol_accuracy:88.3461868
#  batch_molecular_disconnected_validity:100.0000000
#  batch_connected_components:23.0000000
#  batch_invalid_valency_nodes:97.3436161
#  batch_nodes_0degree:22.7200000
#  batch_nodes_7plus_degree:0.0000000
#  invalid_euler_toofew:100.0000000
#  invalid_euler_toomany:0.0000000
#  avg_euler_error:-22.9800000
#  batch_node_degree:0.0359897
# Epoch 193
# train_0.out
# Losses Epoch 193, train
#  fgw:0.5282017
#  conn_penalty:0.0000000
#  val_penalty:0.0000000
#  euler_penalty:0.0000000
#  total:0.5282017
# Measure Epoch 193, train
#  similarity:0.0148118
#  penlog:-0.7085059
# Metrics Epoch 193, train
#  batch_molecular_validity:0.0000000
#  batch_correctness:0.0000000
#  batch_symbol_accuracy:88.0891174
#  batch_molecular_disconnected_validity:98.0000000
#  batch_connected_components:22.0600000
#  batch_invalid_valency_nodes:92.2022279
#  batch_nodes_0degree:21.4600000
#  batch_nodes_7plus_degree:0.0200000
#  invalid_euler_toofew:100.0000000
#  invalid_euler_toomany:0.0000000
#  avg_euler_error:-21.8400000
#  batch_node_degree:0.1285347
# Epoch 194
# train_0.out
# Losses Epoch 194, train
#  fgw:0.5299375
#  conn_penalty:0.0000000
#  val_penalty:0.0000000
#  euler_penalty:0.0000000
#  total:0.5299375
# Measure Epoch 194, train
#  similarity:0.0022039
#  penlog:1.0700442
# Metrics Epoch 194, train
#  batch_molecular_validity:0.0000000
#  batch_correctness:0.0000000
#  batch_symbol_accuracy:86.8894602
#  batch_molecular_disconnected_validity:100.0000000
#  batch_connected_components:23.3000000
#  batch_invalid_valency_nodes:99.6572408
#  batch_nodes_0degree:23.2600000
#  batch_nodes_7plus_degree:0.0000000
#  invalid_euler_toofew:100.0000000
#  invalid_euler_toomany:0.0000000
#  avg_euler_error:-23.3000000
#  batch_node_degree:0.0034276
# Epoch 195
# train_0.out
# Losses Epoch 195, train
#  fgw:0.5270739
#  conn_penalty:0.0000000
#  val_penalty:0.0000000
#  euler_penalty:0.0000000
#  total:0.5270739
# Measure Epoch 195, train
#  similarity:0.0015789
#  penlog:1.0458490
# Metrics Epoch 195, train
#  batch_molecular_validity:0.0000000
#  batch_correctness:0.0000000
#  batch_symbol_accuracy:87.2322194
#  batch_molecular_disconnected_validity:100.0000000
#  batch_connected_components:23.3400000
#  batch_invalid_valency_nodes:100.0000000
#  batch_nodes_0degree:23.3400000
#  batch_nodes_7plus_degree:0.0000000
#  invalid_euler_toofew:100.0000000
#  invalid_euler_toomany:0.0000000
#  avg_euler_error:-23.3400000
#  batch_node_degree:0.0000000
# Epoch 196
# train_0.out
# Losses Epoch 196, train
#  fgw:0.5327998
#  conn_penalty:0.0000000
#  val_penalty:0.0000000
#  euler_penalty:0.0000000
#  total:0.5327998
# Measure Epoch 196, train
#  similarity:0.0044015
#  penlog:1.6438726
# Metrics Epoch 196, train
#  batch_molecular_validity:0.0000000
#  batch_correctness:0.0000000
#  batch_symbol_accuracy:87.4892888
#  batch_molecular_disconnected_validity:100.0000000
#  batch_connected_components:23.1200000
#  batch_invalid_valency_nodes:98.5432734
#  batch_nodes_0degree:23.0000000
#  batch_nodes_7plus_degree:0.0000000
#  invalid_euler_toofew:100.0000000
#  invalid_euler_toomany:0.0000000
#  avg_euler_error:-23.1200000
#  batch_node_degree:0.0188518
# Currently at epoch 196. Sleeping...
# Epoch 196
# Epoch 197
# train_0.out
# Losses Epoch 197, train
#  fgw:0.5367202
#  conn_penalty:0.0000000
#  val_penalty:0.0000000
#  euler_penalty:0.0000000
#  total:0.5367202
# Measure Epoch 197, train
#  similarity:0.0155011
#  penlog:-0.2312472
# Metrics Epoch 197, train
#  batch_molecular_validity:0.0000000
#  batch_correctness:0.0000000
#  batch_symbol_accuracy:87.8320480
#  batch_molecular_disconnected_validity:98.0000000
#  batch_connected_components:20.5800000
#  batch_invalid_valency_nodes:83.5475578
#  batch_nodes_0degree:19.4600000
#  batch_nodes_7plus_degree:0.0000000
#  invalid_euler_toofew:100.0000000
#  invalid_euler_toomany:0.0000000
#  avg_euler_error:-20.1600000
#  batch_node_degree:0.2724936
# Epoch 198
# train_0.out
# Losses Epoch 198, train
#  fgw:0.5247601
#  conn_penalty:0.0000000
#  val_penalty:0.0000000
#  euler_penalty:0.0000000
#  total:0.5247601
# Measure Epoch 198, train
#  similarity:0.0104179
#  penlog:1.3878887
# Metrics Epoch 198, train
#  batch_molecular_validity:0.0000000
#  batch_correctness:0.0000000
#  batch_symbol_accuracy:88.6032562
#  batch_molecular_disconnected_validity:100.0000000
#  batch_connected_components:22.7400000
#  batch_invalid_valency_nodes:95.7155099
#  batch_nodes_0degree:22.3400000
#  batch_nodes_7plus_degree:0.0000000
#  invalid_euler_toofew:100.0000000
#  invalid_euler_toomany:0.0000000
#  avg_euler_error:-22.7400000
#  batch_node_degree:0.0514139
# Epoch 199
# train_0.out
# Losses Epoch 199, train
#  fgw:0.5335904
#  conn_penalty:0.0000000
#  val_penalty:0.0000000
#  euler_penalty:0.0000000
#  total:0.5335904
# Measure Epoch 199, train
#  similarity:0.0015789
#  penlog:1.0862536
# Metrics Epoch 199, train
#  batch_molecular_validity:0.0000000
#  batch_correctness:0.0000000
#  batch_symbol_accuracy:87.4035990
#  batch_molecular_disconnected_validity:100.0000000
#  batch_connected_components:23.3400000
#  batch_invalid_valency_nodes:100.0000000
#  batch_nodes_0degree:23.3400000
#  batch_nodes_7plus_degree:0.0000000
#  invalid_euler_toofew:100.0000000
#  invalid_euler_toomany:0.0000000
#  avg_euler_error:-23.3400000
#  batch_node_degree:0.0000000
# Epoch 200
# train_0.out
# Losses Epoch 200, train
#  fgw:0.5348455
#  conn_penalty:0.0000000
#  val_penalty:0.0000000
#  euler_penalty:0.0000000
#  total:0.5348455
# Measure Epoch 200, train
#  similarity:0.0015789
#  penlog:0.1895985
# Metrics Epoch 200, train
#  batch_molecular_validity:0.0000000
#  batch_correctness:0.0000000
#  batch_symbol_accuracy:86.1182519
#  batch_molecular_disconnected_validity:100.0000000
#  batch_connected_components:23.3400000
#  batch_invalid_valency_nodes:100.0000000
#  batch_nodes_0degree:23.3400000
#  batch_nodes_7plus_degree:0.0000000
#  invalid_euler_toofew:100.0000000
#  invalid_euler_toomany:0.0000000
#  avg_euler_error:-23.3400000
#  batch_node_degree:0.0000000
# Epoch 201
# train_0.out
# Losses Epoch 201, train
#  fgw:0.5346232
#  conn_penalty:0.0000000
#  val_penalty:0.0000000
#  euler_penalty:0.0000000
#  total:0.5346232
# Measure Epoch 201, train
#  similarity:0.0065951
#  penlog:1.0775407
# Metrics Epoch 201, train
#  batch_molecular_validity:0.0000000
#  batch_correctness:0.0000000
#  batch_symbol_accuracy:87.0608398
#  batch_molecular_disconnected_validity:100.0000000
#  batch_connected_components:22.9000000
#  batch_invalid_valency_nodes:96.4867181
#  batch_nodes_0degree:22.5200000
#  batch_nodes_7plus_degree:0.0000000
#  invalid_euler_toofew:100.0000000
#  invalid_euler_toomany:0.0000000
#  avg_euler_error:-22.9000000
#  batch_node_degree:0.0377035
# Epoch 202
# train_0.out
# Losses Epoch 202, train
#  fgw:0.5302807
#  conn_penalty:0.0000000
#  val_penalty:0.0000000
#  euler_penalty:0.0000000
#  total:0.5302807
# Measure Epoch 202, train
#  similarity:0.0076583
#  penlog:1.3198183
# Metrics Epoch 202, train
#  batch_molecular_validity:0.0000000
#  batch_correctness:0.0000000
#  batch_symbol_accuracy:87.0608398
#  batch_molecular_disconnected_validity:100.0000000
#  batch_connected_components:22.8600000
#  batch_invalid_valency_nodes:96.4010283
#  batch_nodes_0degree:22.5000000
#  batch_nodes_7plus_degree:0.0000000
#  invalid_euler_toofew:100.0000000
#  invalid_euler_toomany:0.0000000
#  avg_euler_error:-22.8600000
#  batch_node_degree:0.0411311
# Currently at epoch 202. Sleeping...
# Epoch 202
# Epoch 203
# train_0.out
# Losses Epoch 203, train
#  fgw:0.5250022
#  conn_penalty:0.0000000
#  val_penalty:0.0000000
#  euler_penalty:0.0000000
#  total:0.5250022
# Measure Epoch 203, train
#  similarity:0.0015789
#  penlog:0.8840161
# Metrics Epoch 203, train
#  batch_molecular_validity:0.0000000
#  batch_correctness:0.0000000
#  batch_symbol_accuracy:87.3179092
#  batch_molecular_disconnected_validity:100.0000000
#  batch_connected_components:23.3200000
#  batch_invalid_valency_nodes:99.8286204
#  batch_nodes_0degree:23.3000000
#  batch_nodes_7plus_degree:0.0000000
#  invalid_euler_toofew:100.0000000
#  invalid_euler_toomany:0.0000000
#  avg_euler_error:-23.3200000
#  batch_node_degree:0.0017138
# Epoch 204
# train_0.out
# Losses Epoch 204, train
#  fgw:0.5231727
#  conn_penalty:0.0000000
#  val_penalty:0.0000000
#  euler_penalty:0.0000000
#  total:0.5231727
# Measure Epoch 204, train
#  similarity:0.0015789
#  penlog:1.2112556
# Metrics Epoch 204, train
#  batch_molecular_validity:0.0000000
#  batch_correctness:0.0000000
#  batch_symbol_accuracy:86.8894602
#  batch_molecular_disconnected_validity:100.0000000
#  batch_connected_components:23.3400000
#  batch_invalid_valency_nodes:100.0000000
#  batch_nodes_0degree:23.3400000
#  batch_nodes_7plus_degree:0.0000000
#  invalid_euler_toofew:100.0000000
#  invalid_euler_toomany:0.0000000
#  avg_euler_error:-23.3400000
#  batch_node_degree:0.0000000
# Epoch 205
# train_0.out
# Losses Epoch 205, train
#  fgw:0.5182212
#  conn_penalty:0.0000000
#  val_penalty:0.0000000
#  euler_penalty:0.0000000
#  total:0.5182212
# Measure Epoch 205, train
#  similarity:0.0015526
#  penlog:1.9218480
# Metrics Epoch 205, train
#  batch_molecular_validity:0.0000000
#  batch_correctness:0.0000000
#  batch_symbol_accuracy:86.7180805
#  batch_molecular_disconnected_validity:100.0000000
#  batch_connected_components:23.3000000
#  batch_invalid_valency_nodes:99.6572408
#  batch_nodes_0degree:23.2600000
#  batch_nodes_7plus_degree:0.0000000
#  invalid_euler_toofew:100.0000000
#  invalid_euler_toomany:0.0000000
#  avg_euler_error:-23.3000000
#  batch_node_degree:0.0034276
# Epoch 206
# train_0.out
# Losses Epoch 206, train
#  fgw:0.5315543
#  conn_penalty:0.0000000
#  val_penalty:0.0000000
#  euler_penalty:0.0000000
#  total:0.5315543
# Measure Epoch 206, train
#  similarity:0.0042886
#  penlog:2.1133644
# Metrics Epoch 206, train
#  batch_molecular_validity:0.0000000
#  batch_correctness:0.0000000
#  batch_symbol_accuracy:85.6041131
#  batch_molecular_disconnected_validity:100.0000000
#  batch_connected_components:23.1000000
#  batch_invalid_valency_nodes:98.0291345
#  batch_nodes_0degree:22.8800000
#  batch_nodes_7plus_degree:0.0000000
#  invalid_euler_toofew:100.0000000
#  invalid_euler_toomany:0.0000000
#  avg_euler_error:-23.1000000
#  batch_node_degree:0.0205656
# Epoch 207
# train_0.out
# Losses Epoch 207, train
#  fgw:0.5137808
#  conn_penalty:0.0000000
#  val_penalty:0.0000000
#  euler_penalty:0.0000000
#  total:0.5137808
# Measure Epoch 207, train
#  similarity:0.0078366
#  penlog:-0.6961760
# Metrics Epoch 207, train
#  batch_molecular_validity:0.0000000
#  batch_correctness:0.0000000
#  batch_symbol_accuracy:88.0034276
#  batch_molecular_disconnected_validity:98.0000000
#  batch_connected_components:22.8000000
#  batch_invalid_valency_nodes:96.1439589
#  batch_nodes_0degree:22.4200000
#  batch_nodes_7plus_degree:0.0000000
#  invalid_euler_toofew:100.0000000
#  invalid_euler_toomany:0.0000000
#  avg_euler_error:-22.8000000
#  batch_node_degree:0.0497001
# Epoch 208
# train_0.out
# Losses Epoch 208, train
#  fgw:0.5100723
#  conn_penalty:0.0000000
#  val_penalty:0.0000000
#  euler_penalty:0.0000000
#  total:0.5100723
# Measure Epoch 208, train
#  similarity:0.0020441
#  penlog:0.8439559
# Metrics Epoch 208, train
#  batch_molecular_validity:0.0000000
#  batch_correctness:0.0000000
#  batch_symbol_accuracy:87.1465296
#  batch_molecular_disconnected_validity:100.0000000
#  batch_connected_components:23.2800000
#  batch_invalid_valency_nodes:99.4858612
#  batch_nodes_0degree:23.2200000
#  batch_nodes_7plus_degree:0.0000000
#  invalid_euler_toofew:100.0000000
#  invalid_euler_toomany:0.0000000
#  avg_euler_error:-23.2800000
#  batch_node_degree:0.0051414
# Epoch 209
# Currently at epoch 209. Sleeping...
# Epoch 209
# train_0.out
# Losses Epoch 209, train
#  fgw:0.5211198
#  conn_penalty:0.0000000
#  val_penalty:0.0000000
#  euler_penalty:0.0000000
#  total:0.5211198
# Measure Epoch 209, train
#  similarity:0.0015789
#  penlog:1.1464055
# Metrics Epoch 209, train
#  batch_molecular_validity:0.0000000
#  batch_correctness:0.0000000
#  batch_symbol_accuracy:88.3461868
#  batch_molecular_disconnected_validity:100.0000000
#  batch_connected_components:23.3400000
#  batch_invalid_valency_nodes:100.0000000
#  batch_nodes_0degree:23.3400000
#  batch_nodes_7plus_degree:0.0000000
#  invalid_euler_toofew:100.0000000
#  invalid_euler_toomany:0.0000000
#  avg_euler_error:-23.3400000
#  batch_node_degree:0.0000000
# Epoch 210
# train_0.out
# Losses Epoch 210, train
#  fgw:0.5020019
#  conn_penalty:0.0000000
#  val_penalty:0.0000000
#  euler_penalty:0.0000000
#  total:0.5020019
# Measure Epoch 210, train
#  similarity:0.0015669
#  penlog:1.2960179
# Metrics Epoch 210, train
#  batch_molecular_validity:0.0000000
#  batch_correctness:0.0000000
#  batch_symbol_accuracy:88.1748072
#  batch_molecular_disconnected_validity:100.0000000
#  batch_connected_components:23.3200000
#  batch_invalid_valency_nodes:99.8286204
#  batch_nodes_0degree:23.3000000
#  batch_nodes_7plus_degree:0.0000000
#  invalid_euler_toofew:100.0000000
#  invalid_euler_toomany:0.0000000
#  avg_euler_error:-23.3200000
#  batch_node_degree:0.0017138
# Epoch 211
# train_0.out
# Losses Epoch 211, train
#  fgw:0.5226337
#  conn_penalty:0.0000000
#  val_penalty:0.0000000
#  euler_penalty:0.0000000
#  total:0.5226337
# Measure Epoch 211, train
#  similarity:0.0077236
#  penlog:1.4100505
# Metrics Epoch 211, train
#  batch_molecular_validity:0.0000000
#  batch_correctness:0.0000000
#  batch_symbol_accuracy:88.6032562
#  batch_molecular_disconnected_validity:100.0000000
#  batch_connected_components:22.6800000
#  batch_invalid_valency_nodes:95.7155099
#  batch_nodes_0degree:22.3400000
#  batch_nodes_7plus_degree:0.0000000
#  invalid_euler_toofew:100.0000000
#  invalid_euler_toomany:0.0000000
#  avg_euler_error:-22.6400000
#  batch_node_degree:0.0599829
# Epoch 212
# train_0.out
# Losses Epoch 212, train
#  fgw:0.5103817
#  conn_penalty:0.0000000
#  val_penalty:0.0000000
#  euler_penalty:0.0000000
#  total:0.5103817
# Measure Epoch 212, train
#  similarity:0.0075503
#  penlog:1.2405095
# Metrics Epoch 212, train
#  batch_molecular_validity:0.0000000
#  batch_correctness:0.0000000
#  batch_symbol_accuracy:88.3461868
#  batch_molecular_disconnected_validity:100.0000000
#  batch_connected_components:22.6400000
#  batch_invalid_valency_nodes:95.3727506
#  batch_nodes_0degree:22.2600000
#  batch_nodes_7plus_degree:0.0000000
#  invalid_euler_toofew:100.0000000
#  invalid_euler_toomany:0.0000000
#  avg_euler_error:-22.5400000
#  batch_node_degree:0.0685518
# Epoch 213
# ...
#  batch_correctness:0.0000000
#  batch_symbol_accuracy:93.8303342
#  batch_molecular_disconnected_validity:86.0000000
#  batch_connected_components:12.8600000
#  batch_invalid_valency_nodes:24.9357326
#  batch_nodes_0degree:5.6800000
#  batch_nodes_7plus_degree:0.0000000
#  invalid_euler_toofew:96.0000000
#  invalid_euler_toomany:0.0000000
#  avg_euler_error:-12.8200000
#  batch_node_degree:1.4344473
# Epoch 4000
# train_0.out
# Losses Epoch 4000, train
#  fgw:0.2669596
#  conn_penalty:0.0000000
#  val_penalty:0.0000000
#  euler_penalty:0.0000000
#  total:0.2669596
# Measure Epoch 4000, train
#  similarity:0.0486498
#  penlog:-25.7293089
# Metrics Epoch 4000, train
#  batch_molecular_validity:2.0000000
#  batch_correctness:0.0000000
#  batch_symbol_accuracy:94.5158526
#  batch_molecular_disconnected_validity:74.0000000
#  batch_connected_components:11.8400000
#  batch_invalid_valency_nodes:21.8508997
#  batch_nodes_0degree:4.7400000
#  batch_nodes_7plus_degree:0.0000000
#  invalid_euler_toofew:94.0000000
#  invalid_euler_toomany:0.0000000
#  avg_euler_error:-11.6200000
#  batch_node_degree:1.5801200
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
# Epoch 4000
# Currently at epoch 4000. Sleeping...
