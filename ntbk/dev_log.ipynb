# %%
import os
if "ntbk" in os.getcwd():
    os.chdir("..")
print(os.getcwd())

import sys
sys.path.append(os.path.join(os.getcwd(), "otgnn"))


# %load_ext autoreload
# %autoreload 2

from otgnn.models import GCN
from otgnn.graph import MolGraph
from otgnn.utils import save_model, load_model

from mol_opt.mol_opt import MolOpt
from mol_opt.data_mol_opt import MolOptDataset
from mol_opt.data_mol_opt import get_loader
from mol_opt.arguments import get_args
from mol_opt.train_mol_opt import main, get_latest_model
from mol_opt.ot_utils import compute_barycenter
from mol_opt.log_mol_opt import format_data_name, load_data, save_data
from mol_opt.task_metrics import measure_task
from otgnn.utils import save_model, load_model, StatsTracker, log_tensorboard
from molgen.metrics.mol_metrics import MolMetrics
from tensorboardX import SummaryWriter
from mol_opt.log_mol_opt import do_epoch, main
from otgnn.graph import SYMBOLS, FORMAL_CHARGES, BOND_TYPES
from pathlib import Path

from rdkit.Chem import MolFromSmiles

import torch
import numpy as np
import time
import torch.nn.functional as F
# Out:
# /home/octav/gitrepos/tum-thesis

# %%
model_type = "molemb"
sys.argv = ["", "-cuda", "-model_type", model_type, "-one_batch_train"]
args = get_args()
outdir_suffix = "dev3"
args.init_model = "{}-base-longer-softmax5".format(model_type)
args.output_dir = "mol_opt/output_{}/{}".format(outdir_suffix, args.init_model)
args.tb_logs_dir = "mol_opt/logs_{}/{}".format(outdir_suffix, args.init_model)

print (args.output_dir)
print (args.tb_logs_dir)
# Out:
# mol_opt/output_dev3/molemb-base-longer-softmax5
# mol_opt/logs_dev3/molemb-base-longer-softmax5

# %%
main(args.output_dir, args.tb_logs_dir, 4000)
# Out:
# Epoch 4002
# Epoch 4003
# Epoch 4004
# Epoch 4005
# Epoch 4006
# Epoch 4007
# Epoch 4008
# Epoch 4009
# Epoch 4010
# Epoch 4011
# Epoch 4012
# Epoch 4013
# Epoch 4014
# Epoch 4015
# Epoch 4016
# Epoch 4017
# Epoch 4018
# Epoch 4019
# Epoch 4020
# Epoch 4021
# Epoch 4022
# Epoch 4023
# Epoch 4024
# Epoch 4025
# Epoch 4026
# Epoch 4027
# Epoch 4028
# Epoch 4029
# Epoch 4030
# Epoch 4031
# Epoch 4032
# Epoch 4033
# Epoch 4034
# Epoch 4035
# Epoch 4036
# Epoch 4037
# Epoch 4038
# Epoch 4039
# Epoch 4040
# Epoch 4041
# Epoch 4042
# Epoch 4043
# Epoch 4044
# Epoch 4045
# Epoch 4046
# Epoch 4047
# Epoch 4048
# Epoch 4049
# Epoch 4050
# train_0.out
# fgw 0.16728385925292968
# conn_penalty 0.33258255004882814
# val_penalty 0.4935187911987305
# euler_penalty 4.879659729003906
# total 0.17327035903930665
# Losses Epoch 4050, train
#  fgw:0.1672839
#  conn_penalty:0.3325826
#  val_penalty:0.4935188
#  euler_penalty:4.8796597
#  total:0.1732704
# Measure Epoch 4050, train
#  similarity:0.1121655
#  penlog:-22.2644895
# Metrics Epoch 4050, train
#  batch_molecular_validity:4.0000000
#  batch_correctness:0.0000000
#  batch_symbol_accuracy:100.0000000
#  batch_molecular_disconnected_validity:78.0000000
#  batch_connected_components:6.6000000
#  batch_invalid_valency_nodes:2.0869565
#  batch_nodes_0degree:0.2000000
#  batch_nodes_7plus_degree:0.0000000
#  invalid_euler_toofew:86.0000000
#  invalid_euler_toomany:0.0000000
#  avg_euler_error:-5.9000000
#  batch_node_degree:2.1426087
# Epoch 4051
# train_0.out
# fgw 0.1681128692626953
# conn_penalty 0.35538177490234374
# val_penalty 0.5251569366455078
# euler_penalty 4.84616455078125
# total 0.1741275405883789
# Losses Epoch 4051, train
#  fgw:0.1681129
#  conn_penalty:0.3553818
#  val_penalty:0.5251569
#  euler_penalty:4.8461646
#  total:0.1741275
# Measure Epoch 4051, train
#  similarity:0.1057253
#  penlog:-22.0903945
# Metrics Epoch 4051, train
#  batch_molecular_validity:6.0000000
#  batch_correctness:0.0000000
#  batch_symbol_accuracy:100.0000000
#  batch_molecular_disconnected_validity:78.0000000
#  batch_connected_components:6.4600000
#  batch_invalid_valency_nodes:2.4347826
#  batch_nodes_0degree:0.2400000
#  batch_nodes_7plus_degree:0.0000000
#  invalid_euler_toofew:84.0000000
#  invalid_euler_toomany:0.0000000
#  avg_euler_error:-5.7600000
#  batch_node_degree:2.1478261
# Epoch 4052
# train_0.out
# fgw 0.16619470596313476
# conn_penalty 0.405040283203125
# val_penalty 0.48653957366943357
# euler_penalty 5.028009948730468
# total 0.1724180221557617
# Losses Epoch 4052, train
#  fgw:0.1661947
#  conn_penalty:0.4050403
#  val_penalty:0.4865396
#  euler_penalty:5.0280099
#  total:0.1724180
# Measure Epoch 4052, train
#  similarity:0.1068326
#  penlog:-20.0071630
# Metrics Epoch 4052, train
#  batch_molecular_validity:6.0000000
#  batch_correctness:0.0000000
#  batch_symbol_accuracy:100.0000000
#  batch_molecular_disconnected_validity:80.0000000
#  batch_connected_components:6.7200000
#  batch_invalid_valency_nodes:2.5217391
#  batch_nodes_0degree:0.3000000
#  batch_nodes_7plus_degree:0.0200000
#  invalid_euler_toofew:86.0000000
#  invalid_euler_toomany:0.0000000
#  avg_euler_error:-6.0400000
#  batch_node_degree:2.1217391
# Epoch 4053
# train_0.out
# fgw 0.15626937866210938
# conn_penalty 0.38912673950195314
# val_penalty 0.4677233505249023
# euler_penalty 5.2158544921875
# total 0.1626598358154297
# Losses Epoch 4053, train
#  fgw:0.1562694
#  conn_penalty:0.3891267
#  val_penalty:0.4677234
#  euler_penalty:5.2158545
#  total:0.1626598
# Measure Epoch 4053, train
#  similarity:0.1157373
#  penlog:-16.0291767
# Metrics Epoch 4053, train
#  batch_molecular_validity:4.0000000
#  batch_correctness:0.0000000
#  batch_symbol_accuracy:100.0000000
#  batch_molecular_disconnected_validity:84.0000000
#  batch_connected_components:6.9200000
#  batch_invalid_valency_nodes:2.3478261
#  batch_nodes_0degree:0.3600000
#  batch_nodes_7plus_degree:0.0200000
#  invalid_euler_toofew:94.0000000
#  invalid_euler_toomany:0.0000000
#  avg_euler_error:-6.4400000
#  batch_node_degree:2.0886957
# Epoch 4054
# train_0.out
# fgw 0.16635923385620116
# conn_penalty 0.36999008178710935
# val_penalty 0.5060894393920898
# euler_penalty 5.186373291015625
# total 0.172745418548584
# Losses Epoch 4054, train
#  fgw:0.1663592
#  conn_penalty:0.3699901
#  val_penalty:0.5060894
#  euler_penalty:5.1863733
#  total:0.1727454
# Measure Epoch 4054, train
#  similarity:0.1066037
#  penlog:-20.3415124
# Metrics Epoch 4054, train
#  batch_molecular_validity:6.0000000
#  batch_correctness:0.0000000
#  batch_symbol_accuracy:100.0000000
#  batch_molecular_disconnected_validity:80.0000000
#  batch_connected_components:6.8200000
#  batch_invalid_valency_nodes:2.7826087
#  batch_nodes_0degree:0.3600000
#  batch_nodes_7plus_degree:0.0200000
#  invalid_euler_toofew:90.0000000
#  invalid_euler_toomany:0.0000000
#  avg_euler_error:-6.2200000
#  batch_node_degree:2.1130435
# Epoch 4055
# train_0.out
# fgw 0.1650039291381836
# conn_penalty 0.23979843139648438
# val_penalty 0.5008489227294922
# euler_penalty 4.986530456542969
# total 0.17104286193847656
# Losses Epoch 4055, train
#  fgw:0.1650039
#  conn_penalty:0.2397984
#  val_penalty:0.5008489
#  euler_penalty:4.9865305
#  total:0.1710429
# Measure Epoch 4055, train
#  similarity:0.1213666
#  penlog:-18.2832518
# Metrics Epoch 4055, train
#  batch_molecular_validity:6.0000000
#  batch_correctness:0.0000000
#  batch_symbol_accuracy:100.0000000
#  batch_molecular_disconnected_validity:82.0000000
#  batch_connected_components:6.6800000
#  batch_invalid_valency_nodes:2.5217391
#  batch_nodes_0degree:0.3400000
#  batch_nodes_7plus_degree:0.0000000
#  invalid_euler_toofew:88.0000000
#  invalid_euler_toomany:0.0000000
#  avg_euler_error:-6.1000000
#  batch_node_degree:2.1217391
# Epoch 4056
# train_0.out
# fgw 0.16407501220703125
# conn_penalty 0.3438615417480469
# val_penalty 0.4406710433959961
# euler_penalty 5.106809692382813
# total 0.17029308319091796
# Losses Epoch 4056, train
#  fgw:0.1640750
#  conn_penalty:0.3438615
#  val_penalty:0.4406710
#  euler_penalty:5.1068097
#  total:0.1702931
# Measure Epoch 4056, train
#  similarity:0.1253881
#  penlog:-10.2335262
# Metrics Epoch 4056, train
#  batch_molecular_validity:4.0000000
#  batch_correctness:0.0000000
#  batch_symbol_accuracy:100.0000000
#  batch_molecular_disconnected_validity:90.0000000
#  batch_connected_components:6.7000000
#  batch_invalid_valency_nodes:2.2608696
#  batch_nodes_0degree:0.3800000
#  batch_nodes_7plus_degree:0.0000000
#  invalid_euler_toofew:94.0000000
#  invalid_euler_toomany:0.0000000
#  avg_euler_error:-6.2000000
#  batch_node_degree:2.1060870
# Epoch 4057
# train_0.out
# fgw 0.16208868026733397
# conn_penalty 0.4276385498046875
# val_penalty 0.4806978225708008
# euler_penalty 4.989690551757812
# total 0.16832046508789061
# Losses Epoch 4057, train
#  fgw:0.1620887
#  conn_penalty:0.4276385
#  val_penalty:0.4806978
#  euler_penalty:4.9896906
#  total:0.1683205
# Measure Epoch 4057, train
#  similarity:0.1219181
#  penlog:-14.3919338
# Metrics Epoch 4057, train
#  batch_molecular_validity:6.0000000
#  batch_correctness:0.0000000
#  batch_symbol_accuracy:100.0000000
#  batch_molecular_disconnected_validity:86.0000000
#  batch_connected_components:6.7400000
#  batch_invalid_valency_nodes:2.2608696
#  batch_nodes_0degree:0.3800000
#  batch_nodes_7plus_degree:0.0000000
#  invalid_euler_toofew:92.0000000
#  invalid_euler_toomany:0.0000000
#  avg_euler_error:-6.1600000
#  batch_node_degree:2.1043478
# Epoch 4058
# train_0.out
# fgw 0.16941471099853517
# conn_penalty 0.37262298583984377
# val_penalty 0.5440423202514648
# euler_penalty 4.802127075195313
# total 0.1754634666442871
# Losses Epoch 4058, train
#  fgw:0.1694147
#  conn_penalty:0.3726230
#  val_penalty:0.5440423
#  euler_penalty:4.8021271
#  total:0.1754635
# Measure Epoch 4058, train
#  similarity:0.1212622
#  penlog:-18.5309974
# Metrics Epoch 4058, train
#  batch_molecular_validity:4.0000000
#  batch_correctness:0.0000000
#  batch_symbol_accuracy:100.0000000
#  batch_molecular_disconnected_validity:82.0000000
#  batch_connected_components:6.6000000
#  batch_invalid_valency_nodes:2.4347826
#  batch_nodes_0degree:0.2800000
#  batch_nodes_7plus_degree:0.0000000
#  invalid_euler_toofew:94.0000000
#  invalid_euler_toomany:0.0000000
#  avg_euler_error:-5.9400000
#  batch_node_degree:2.1339130
# Epoch 4059
# train_0.out
# fgw 0.15345925331115723
# conn_penalty 0.37049713134765627
# val_penalty 0.47447898864746096
# euler_penalty 4.957850646972656
# total 0.15960261344909668
# Losses Epoch 4059, train
#  fgw:0.1534593
#  conn_penalty:0.3704971
#  val_penalty:0.4744790
#  euler_penalty:4.9578506
#  total:0.1596026
# Measure Epoch 4059, train
#  similarity:0.1435867
#  penlog:-14.7319166
# Metrics Epoch 4059, train
#  batch_molecular_validity:6.0000000
#  batch_correctness:0.0000000
#  batch_symbol_accuracy:100.0000000
#  batch_molecular_disconnected_validity:86.0000000
#  batch_connected_components:6.6200000
#  batch_invalid_valency_nodes:2.0000000
#  batch_nodes_0degree:0.2800000
#  batch_nodes_7plus_degree:0.0000000
#  invalid_euler_toofew:88.0000000
#  invalid_euler_toomany:0.0000000
#  avg_euler_error:-6.0400000
#  batch_node_degree:2.1252174
# Epoch 4060
# train_0.out
# fgw 0.16476924896240233
# conn_penalty 0.33428619384765623
# val_penalty 0.49819713592529297
# euler_penalty 4.9237890625
# total 0.17086950302124024
# Losses Epoch 4060, train
#  fgw:0.1647692
#  conn_penalty:0.3342862
#  val_penalty:0.4981971
#  euler_penalty:4.9237891
#  total:0.1708695
# Measure Epoch 4060, train
#  similarity:0.1309629
#  penlog:-16.3728681
# Metrics Epoch 4060, train
#  batch_molecular_validity:6.0000000
#  batch_correctness:0.0000000
#  batch_symbol_accuracy:100.0000000
#  batch_molecular_disconnected_validity:84.0000000
#  batch_connected_components:6.5000000
#  batch_invalid_valency_nodes:2.0869565
#  batch_nodes_0degree:0.2600000
#  batch_nodes_7plus_degree:0.0000000
#  invalid_euler_toofew:86.0000000
#  invalid_euler_toomany:0.0000000
#  avg_euler_error:-5.8400000
#  batch_node_degree:2.1426087
# Epoch 4061
# train_0.out
# fgw 0.15657925605773926
# conn_penalty 0.33920623779296877
# val_penalty 0.4491094207763672
# euler_penalty 4.9637057495117185
# total 0.16268083572387695
# Losses Epoch 4061, train
#  fgw:0.1565793
#  conn_penalty:0.3392062
#  val_penalty:0.4491094
#  euler_penalty:4.9637057
#  total:0.1626808
# Measure Epoch 4061, train
#  similarity:0.1285686
#  penlog:-16.3656070
# Metrics Epoch 4061, train
#  batch_molecular_validity:6.0000000
#  batch_correctness:0.0000000
#  batch_symbol_accuracy:100.0000000
#  batch_molecular_disconnected_validity:84.0000000
#  batch_connected_components:6.4400000
#  batch_invalid_valency_nodes:2.1739130
#  batch_nodes_0degree:0.3000000
#  batch_nodes_7plus_degree:0.0200000
#  invalid_euler_toofew:88.0000000
#  invalid_euler_toomany:0.0000000
#  avg_euler_error:-5.8600000
#  batch_node_degree:2.1304348
# Epoch 4062
# train_0.out
# fgw 0.1613201904296875
# conn_penalty 0.4653512573242187
# val_penalty 0.44842235565185545
# euler_penalty 5.070015563964843
# total 0.16767414093017577
# Losses Epoch 4062, train
#  fgw:0.1613202
#  conn_penalty:0.4653513
#  val_penalty:0.4484224
#  euler_penalty:5.0700156
#  total:0.1676741
# Measure Epoch 4062, train
#  similarity:0.1177646
#  penlog:-14.2973121
# Metrics Epoch 4062, train
#  batch_molecular_validity:4.0000000
#  batch_correctness:0.0000000
#  batch_symbol_accuracy:100.0000000
#  batch_molecular_disconnected_validity:86.0000000
#  batch_connected_components:6.5400000
#  batch_invalid_valency_nodes:2.0869565
#  batch_nodes_0degree:0.3200000
#  batch_nodes_7plus_degree:0.0200000
#  invalid_euler_toofew:88.0000000
#  invalid_euler_toomany:0.0000000
#  avg_euler_error:-5.9200000
#  batch_node_degree:2.1234783
# Epoch 4063
# train_0.out
# fgw 0.16550762176513673
# conn_penalty 0.4356358337402344
# val_penalty 0.4614758682250977
# euler_penalty 4.987919921875
# total 0.17176301956176757
# Losses Epoch 4063, train
#  fgw:0.1655076
#  conn_penalty:0.4356358
#  val_penalty:0.4614759
#  euler_penalty:4.9879199
#  total:0.1717630
# Measure Epoch 4063, train
#  similarity:0.1285649
#  penlog:-12.3842620
# Metrics Epoch 4063, train
#  batch_molecular_validity:6.0000000
#  batch_correctness:0.0000000
#  batch_symbol_accuracy:100.0000000
#  batch_molecular_disconnected_validity:88.0000000
#  batch_connected_components:6.5400000
#  batch_invalid_valency_nodes:2.0869565
#  batch_nodes_0degree:0.3400000
#  batch_nodes_7plus_degree:0.0200000
#  invalid_euler_toofew:86.0000000
#  invalid_euler_toomany:0.0000000
#  avg_euler_error:-5.9600000
#  batch_node_degree:2.1147826
# Epoch 4064
# train_0.out
# fgw 0.15967671394348146
# conn_penalty 0.3198707580566406
# val_penalty 0.4836550521850586
# euler_penalty 4.741044921875
# total 0.16557619094848633
# Losses Epoch 4064, train
#  fgw:0.1596767
#  conn_penalty:0.3198708
#  val_penalty:0.4836551
#  euler_penalty:4.7410449
#  total:0.1655762
# Measure Epoch 4064, train
#  similarity:0.1162831
#  penlog:-22.2708419
# Metrics Epoch 4064, train
#  batch_molecular_validity:8.0000000
#  batch_correctness:0.0000000
#  batch_symbol_accuracy:100.0000000
#  batch_molecular_disconnected_validity:78.0000000
#  batch_connected_components:6.4000000
#  batch_invalid_valency_nodes:2.4347826
#  batch_nodes_0degree:0.2600000
#  batch_nodes_7plus_degree:0.0000000
#  invalid_euler_toofew:82.0000000
#  invalid_euler_toomany:0.0000000
#  avg_euler_error:-5.6000000
#  batch_node_degree:2.1582609
# Epoch 4065
# train_0.out
# fgw 0.1621714210510254
# conn_penalty 0.28595428466796874
# val_penalty 0.5015901947021484
# euler_penalty 4.656040649414063
# total 0.16796932220458985
# Losses Epoch 4065, train
#  fgw:0.1621714
#  conn_penalty:0.2859543
#  val_penalty:0.5015902
#  euler_penalty:4.6560406
#  total:0.1679693
# Measure Epoch 4065, train
#  similarity:0.1324016
#  penlog:-18.2732119
# Metrics Epoch 4065, train
#  batch_molecular_validity:8.0000000
#  batch_correctness:0.0000000
#  batch_symbol_accuracy:100.0000000
#  batch_molecular_disconnected_validity:82.0000000
#  batch_connected_components:6.4000000
#  batch_invalid_valency_nodes:2.3478261
#  batch_nodes_0degree:0.3000000
#  batch_nodes_7plus_degree:0.0000000
#  invalid_euler_toofew:82.0000000
#  invalid_euler_toomany:0.0000000
#  avg_euler_error:-5.5800000
#  batch_node_degree:2.1530435
# Epoch 4066
# train_0.out
# fgw 0.15825630187988282
# conn_penalty 0.3515911865234375
# val_penalty 0.43430294036865236
# euler_penalty 4.888523864746094
# total 0.1643057060241699
# Losses Epoch 4066, train
#  fgw:0.1582563
#  conn_penalty:0.3515912
#  val_penalty:0.4343029
#  euler_penalty:4.8885239
#  total:0.1643057
# Measure Epoch 4066, train
#  similarity:0.1441613
#  penlog:-8.6864495
# Metrics Epoch 4066, train
#  batch_molecular_validity:8.0000000
#  batch_correctness:0.0000000
#  batch_symbol_accuracy:100.0000000
#  batch_molecular_disconnected_validity:92.0000000
#  batch_connected_components:6.3800000
#  batch_invalid_valency_nodes:1.8260870
#  batch_nodes_0degree:0.3200000
#  batch_nodes_7plus_degree:0.0000000
#  invalid_euler_toofew:84.0000000
#  invalid_euler_toomany:0.0000000
#  avg_euler_error:-5.6600000
#  batch_node_degree:2.1478261
# Epoch 4067
# train_0.out
# fgw 0.1536174774169922
# conn_penalty 0.2789306640625
# val_penalty 0.4203994369506836
# euler_penalty 4.798359069824219
# total 0.159484167098999
# Losses Epoch 4067, train
#  fgw:0.1536175
#  conn_penalty:0.2789307
#  val_penalty:0.4203994
#  euler_penalty:4.7983591
#  total:0.1594842
# Measure Epoch 4067, train
#  similarity:0.1298127
#  penlog:-12.5396952
# Metrics Epoch 4067, train
#  batch_molecular_validity:10.0000000
#  batch_correctness:0.0000000
#  batch_symbol_accuracy:100.0000000
#  batch_molecular_disconnected_validity:88.0000000
#  batch_connected_components:6.4000000
#  batch_invalid_valency_nodes:2.0869565
#  batch_nodes_0degree:0.3400000
#  batch_nodes_7plus_degree:0.0000000
#  invalid_euler_toofew:84.0000000
#  invalid_euler_toomany:0.0000000
#  avg_euler_error:-5.6800000
#  batch_node_degree:2.1443478
# Epoch 4068
# train_0.out
# fgw 0.15663190841674804
# conn_penalty 0.17627975463867188
# val_penalty 0.4295405578613281
# euler_penalty 4.457653503417969
# total 0.16204069137573243
# Losses Epoch 4068, train
#  fgw:0.1566319
#  conn_penalty:0.1762798
#  val_penalty:0.4295406
#  euler_penalty:4.4576535
#  total:0.1620407
# Measure Epoch 4068, train
#  similarity:0.1342926
#  penlog:-12.5372041
# Metrics Epoch 4068, train
#  batch_molecular_validity:10.0000000
#  batch_correctness:0.0000000
#  batch_symbol_accuracy:100.0000000
#  batch_molecular_disconnected_validity:88.0000000
#  batch_connected_components:6.1600000
#  batch_invalid_valency_nodes:1.8260870
#  batch_nodes_0degree:0.2400000
#  batch_nodes_7plus_degree:0.0000000
#  invalid_euler_toofew:82.0000000
#  invalid_euler_toomany:0.0000000
#  avg_euler_error:-5.3800000
#  batch_node_degree:2.1739130
# Epoch 4069
# train_0.out
# fgw 0.16799270629882812
# conn_penalty 0.218175048828125
# val_penalty 0.4075997543334961
# euler_penalty 4.5115658569335935
# total 0.17348581314086914
# Losses Epoch 4069, train
#  fgw:0.1679927
#  conn_penalty:0.2181750
#  val_penalty:0.4075998
#  euler_penalty:4.5115659
#  total:0.1734858
# Measure Epoch 4069, train
#  similarity:0.1288452
#  penlog:-14.6042370
# Metrics Epoch 4069, train
#  batch_molecular_validity:10.0000000
#  batch_correctness:0.0000000
#  batch_symbol_accuracy:100.0000000
#  batch_molecular_disconnected_validity:86.0000000
#  batch_connected_components:6.1000000
#  batch_invalid_valency_nodes:1.6521739
#  batch_nodes_0degree:0.2000000
#  batch_nodes_7plus_degree:0.0000000
#  invalid_euler_toofew:82.0000000
#  invalid_euler_toomany:0.0000000
#  avg_euler_error:-5.3000000
#  batch_node_degree:2.1808696
# Epoch 4070
# train_0.out
# fgw 0.15755447387695312
# conn_penalty 0.2253436279296875
# val_penalty 0.3335239028930664
# euler_penalty 4.537467346191407
# total 0.16300872802734376
# Losses Epoch 4070, train
#  fgw:0.1575545
#  conn_penalty:0.2253436
#  val_penalty:0.3335239
#  euler_penalty:4.5374673
#  total:0.1630087
# Measure Epoch 4070, train
#  similarity:0.1291204
#  penlog:-10.5269812
# Metrics Epoch 4070, train
#  batch_molecular_validity:8.0000000
#  batch_correctness:0.0000000
#  batch_symbol_accuracy:100.0000000
#  batch_molecular_disconnected_validity:90.0000000
#  batch_connected_components:6.0800000
#  batch_invalid_valency_nodes:1.5652174
#  batch_nodes_0degree:0.2200000
#  batch_nodes_7plus_degree:0.0000000
#  invalid_euler_toofew:82.0000000
#  invalid_euler_toomany:0.0000000
#  avg_euler_error:-5.3600000
#  batch_node_degree:2.1739130
# Epoch 4071
# train_0.out
# fgw 0.15921767234802245
# conn_penalty 0.3605216979980469
# val_penalty 0.33437252044677734
# euler_penalty 4.513390808105469
# total 0.1647976493835449
# Losses Epoch 4071, train
#  fgw:0.1592177
#  conn_penalty:0.3605217
#  val_penalty:0.3343725
#  euler_penalty:4.5133908
#  total:0.1647976
# Measure Epoch 4071, train
#  similarity:0.1275016
#  penlog:-12.5741780
# Metrics Epoch 4071, train
#  batch_molecular_validity:8.0000000
#  batch_correctness:0.0000000
#  batch_symbol_accuracy:100.0000000
#  batch_molecular_disconnected_validity:88.0000000
#  batch_connected_components:6.1200000
#  batch_invalid_valency_nodes:1.6521739
#  batch_nodes_0degree:0.2200000
#  batch_nodes_7plus_degree:0.0000000
#  invalid_euler_toofew:84.0000000
#  invalid_euler_toomany:0.0000000
#  avg_euler_error:-5.3000000
#  batch_node_degree:2.1791304
# Epoch 4072
# train_0.out
# fgw 0.1605364990234375
# conn_penalty 0.33819366455078126
# val_penalty 0.36212650299072263
# euler_penalty 4.360803833007813
# total 0.16596446990966796
# Losses Epoch 4072, train
#  fgw:0.1605365
#  conn_penalty:0.3381937
#  val_penalty:0.3621265
#  euler_penalty:4.3608038
#  total:0.1659645
# Measure Epoch 4072, train
#  similarity:0.1318147
#  penlog:-16.4714513
# Metrics Epoch 4072, train
#  batch_molecular_validity:4.0000000
#  batch_correctness:0.0000000
#  batch_symbol_accuracy:100.0000000
#  batch_molecular_disconnected_validity:84.0000000
#  batch_connected_components:6.0800000
#  batch_invalid_valency_nodes:1.6521739
#  batch_nodes_0degree:0.1800000
#  batch_nodes_7plus_degree:0.0000000
#  invalid_euler_toofew:82.0000000
#  invalid_euler_toomany:0.0000000
#  avg_euler_error:-5.2400000
#  batch_node_degree:2.1808696
# Epoch 4073
# train_0.out
# fgw 0.16479000091552734
# conn_penalty 0.29064422607421875
# val_penalty 0.39553733825683596
# euler_penalty 4.329521179199219
# total 0.17017473220825197
# Losses Epoch 4073, train
#  fgw:0.1647900
#  conn_penalty:0.2906442
#  val_penalty:0.3955373
#  euler_penalty:4.3295212
#  total:0.1701747
# Measure Epoch 4073, train
#  similarity:0.1346577
#  penlog:-16.4067871
# Metrics Epoch 4073, train
#  batch_molecular_validity:2.0000000
#  batch_correctness:0.0000000
#  batch_symbol_accuracy:100.0000000
#  batch_molecular_disconnected_validity:84.0000000
#  batch_connected_components:6.0800000
#  batch_invalid_valency_nodes:1.8260870
#  batch_nodes_0degree:0.1800000
#  batch_nodes_7plus_degree:0.0000000
#  invalid_euler_toofew:82.0000000
#  invalid_euler_toomany:0.0000000
#  avg_euler_error:-5.2000000
#  batch_node_degree:2.1843478
# Epoch 4074
# train_0.out
# fgw 0.16072248458862304
# conn_penalty 0.3466883850097656
# val_penalty 0.3839219284057617
# euler_penalty 4.509844665527344
# total 0.16635406494140625
# Losses Epoch 4074, train
#  fgw:0.1607225
#  conn_penalty:0.3466884
#  val_penalty:0.3839219
#  euler_penalty:4.5098447
#  total:0.1663541
# Measure Epoch 4074, train
#  similarity:0.1346472
#  penlog:-16.4078811
# Metrics Epoch 4074, train
#  batch_molecular_validity:2.0000000
#  batch_correctness:0.0000000
#  batch_symbol_accuracy:100.0000000
#  batch_molecular_disconnected_validity:84.0000000
#  batch_connected_components:6.1600000
#  batch_invalid_valency_nodes:1.5652174
#  batch_nodes_0degree:0.1800000
#  batch_nodes_7plus_degree:0.0000000
#  invalid_euler_toofew:84.0000000
#  invalid_euler_toomany:0.0000000
#  avg_euler_error:-5.3600000
#  batch_node_degree:2.1721739
# Epoch 4075
# train_0.out
# fgw 0.1582540225982666
# conn_penalty 0.26496673583984376
# val_penalty 0.4265662384033203
# euler_penalty 4.400632934570313
# total 0.1637318801879883
# Losses Epoch 4075, train
#  fgw:0.1582540
#  conn_penalty:0.2649667
#  val_penalty:0.4265662
#  euler_penalty:4.4006329
#  total:0.1637319
# Measure Epoch 4075, train
#  similarity:0.1306583
#  penlog:-20.3288138
# Metrics Epoch 4075, train
#  batch_molecular_validity:4.0000000
#  batch_correctness:0.0000000
#  batch_symbol_accuracy:100.0000000
#  batch_molecular_disconnected_validity:80.0000000
#  batch_connected_components:6.0800000
#  batch_invalid_valency_nodes:1.6521739
#  batch_nodes_0degree:0.1600000
#  batch_nodes_7plus_degree:0.0000000
#  invalid_euler_toofew:80.0000000
#  invalid_euler_toomany:0.0000000
#  avg_euler_error:-5.2600000
#  batch_node_degree:2.1791304
# Epoch 4076
# train_0.out
# fgw 0.1632245635986328
# conn_penalty 0.22800613403320313
# val_penalty 0.4469696044921875
# euler_penalty 4.286678161621094
# total 0.16856752395629881
# Losses Epoch 4076, train
#  fgw:0.1632246
#  conn_penalty:0.2280061
#  val_penalty:0.4469696
#  euler_penalty:4.2866782
#  total:0.1685675
# Measure Epoch 4076, train
#  similarity:0.1236127
#  penlog:-20.4042868
# Metrics Epoch 4076, train
#  batch_molecular_validity:4.0000000
#  batch_correctness:0.0000000
#  batch_symbol_accuracy:100.0000000
#  batch_molecular_disconnected_validity:80.0000000
#  batch_connected_components:6.0800000
#  batch_invalid_valency_nodes:1.6521739
#  batch_nodes_0degree:0.1800000
#  batch_nodes_7plus_degree:0.0000000
#  invalid_euler_toofew:74.0000000
#  invalid_euler_toomany:0.0000000
#  avg_euler_error:-5.2800000
#  batch_node_degree:2.1773913
# Epoch 4077
# train_0.out
# fgw 0.15687118530273436
# conn_penalty 0.301761474609375
# val_penalty 0.3891032791137695
# euler_penalty 4.39120361328125
# total 0.1623489761352539
# Losses Epoch 4077, train
#  fgw:0.1568712
#  conn_penalty:0.3017615
#  val_penalty:0.3891033
#  euler_penalty:4.3912036
#  total:0.1623490
# Measure Epoch 4077, train
#  similarity:0.1200265
#  penlog:-16.5138780
# Metrics Epoch 4077, train
#  batch_molecular_validity:6.0000000
#  batch_correctness:0.0000000
#  batch_symbol_accuracy:100.0000000
#  batch_molecular_disconnected_validity:84.0000000
#  batch_connected_components:6.0400000
#  batch_invalid_valency_nodes:1.6521739
#  batch_nodes_0degree:0.2000000
#  batch_nodes_7plus_degree:0.0000000
#  invalid_euler_toofew:80.0000000
#  invalid_euler_toomany:0.0000000
#  avg_euler_error:-5.2600000
#  batch_node_degree:2.1808696
# Epoch 4078
# train_0.out
# fgw 0.15583566665649415
# conn_penalty 0.45619155883789064
# val_penalty 0.3661611938476563
# euler_penalty 4.4824462890625
# total 0.16155942916870117
# Losses Epoch 4078, train
#  fgw:0.1558357
#  conn_penalty:0.4561916
#  val_penalty:0.3661612
#  euler_penalty:4.4824463
#  total:0.1615594
# Measure Epoch 4078, train
#  similarity:0.1217564
#  penlog:-12.6426200
# Metrics Epoch 4078, train
#  batch_molecular_validity:8.0000000
#  batch_correctness:0.0000000
#  batch_symbol_accuracy:100.0000000
#  batch_molecular_disconnected_validity:88.0000000
#  batch_connected_components:6.2000000
#  batch_invalid_valency_nodes:1.7391304
#  batch_nodes_0degree:0.2200000
#  batch_nodes_7plus_degree:0.0000000
#  invalid_euler_toofew:82.0000000
#  invalid_euler_toomany:0.0000000
#  avg_euler_error:-5.3800000
#  batch_node_degree:2.1704348
# Epoch 4079
# train_0.out
# fgw 0.14948847770690918
# conn_penalty 0.33254150390625
# val_penalty 0.36239185333251955
# euler_penalty 4.313322448730469
# total 0.15489748001098633
# Losses Epoch 4079, train
#  fgw:0.1494885
#  conn_penalty:0.3325415
#  val_penalty:0.3623919
#  euler_penalty:4.3133224
#  total:0.1548975
# Measure Epoch 4079, train
#  similarity:0.1254899
#  penlog:-14.7249638
# Metrics Epoch 4079, train
#  batch_molecular_validity:8.0000000
#  batch_correctness:0.0000000
#  batch_symbol_accuracy:100.0000000
#  batch_molecular_disconnected_validity:86.0000000
#  batch_connected_components:6.0800000
#  batch_invalid_valency_nodes:1.7391304
#  batch_nodes_0degree:0.2200000
#  batch_nodes_7plus_degree:0.0000000
#  invalid_euler_toofew:80.0000000
#  invalid_euler_toomany:0.0000000
#  avg_euler_error:-5.1800000
#  batch_node_degree:2.1843478
# Epoch 4080
# train_0.out
# fgw 0.16156761169433595
# conn_penalty 0.22587936401367187
# val_penalty 0.3465841674804688
# euler_penalty 4.154342956542969
# total 0.16667747497558594
# Losses Epoch 4080, train
#  fgw:0.1615676
#  conn_penalty:0.2258794
#  val_penalty:0.3465842
#  euler_penalty:4.1543430
#  total:0.1666775
# Measure Epoch 4080, train
#  similarity:0.1221616
#  penlog:-16.6698172
# Metrics Epoch 4080, train
#  batch_molecular_validity:8.0000000
#  batch_correctness:0.0000000
#  batch_symbol_accuracy:100.0000000
#  batch_molecular_disconnected_validity:84.0000000
#  batch_connected_components:5.8200000
#  batch_invalid_valency_nodes:1.4782609
#  batch_nodes_0degree:0.1600000
#  batch_nodes_7plus_degree:0.0000000
#  invalid_euler_toofew:78.0000000
#  invalid_euler_toomany:0.0000000
#  avg_euler_error:-4.8800000
#  batch_node_degree:2.2156522
# Epoch 4081
# train_0.out
# fgw 0.16544960021972657
# conn_penalty 0.22938323974609376
# val_penalty 0.3006344032287598
# euler_penalty 4.24862060546875
# total 0.17062026977539063
# Losses Epoch 4081, train
#  fgw:0.1654496
#  conn_penalty:0.2293832
#  val_penalty:0.3006344
#  euler_penalty:4.2486206
#  total:0.1706203
# Measure Epoch 4081, train
#  similarity:0.1255974
#  penlog:-13.2624008
# Metrics Epoch 4081, train
#  batch_molecular_validity:8.0000000
#  batch_correctness:0.0000000
#  batch_symbol_accuracy:100.0000000
#  batch_molecular_disconnected_validity:88.0000000
#  batch_connected_components:5.9400000
#  batch_invalid_valency_nodes:1.3043478
#  batch_nodes_0degree:0.1600000
#  batch_nodes_7plus_degree:0.0000000
#  invalid_euler_toofew:86.0000000
#  invalid_euler_toomany:0.0000000
#  avg_euler_error:-5.0600000
#  batch_node_degree:2.2000000
# Epoch 4082
# train_0.out
# fgw 0.15966790199279784
# conn_penalty 0.28450302124023436
# val_penalty 0.2996365165710449
# euler_penalty 4.404097595214844
# total 0.16507081985473632
# Losses Epoch 4082, train
#  fgw:0.1596679
#  conn_penalty:0.2845030
#  val_penalty:0.2996365
#  euler_penalty:4.4040976
#  total:0.1650708
# Measure Epoch 4082, train
#  similarity:0.1278394
#  penlog:-11.1994635
# Metrics Epoch 4082, train
#  batch_molecular_validity:8.0000000
#  batch_correctness:0.0000000
#  batch_symbol_accuracy:100.0000000
#  batch_molecular_disconnected_validity:90.0000000
#  batch_connected_components:6.0400000
#  batch_invalid_valency_nodes:1.2173913
#  batch_nodes_0degree:0.1600000
#  batch_nodes_7plus_degree:0.0200000
#  invalid_euler_toofew:88.0000000
#  invalid_euler_toomany:0.0000000
#  avg_euler_error:-5.2600000
#  batch_node_degree:2.1860870
# Epoch 4083
# train_0.out
# fgw 0.1547239589691162
# conn_penalty 0.3001617431640625
# val_penalty 0.34945533752441404
# euler_penalty 4.288810729980469
# total 0.16007875442504882
# Losses Epoch 4083, train
#  fgw:0.1547240
#  conn_penalty:0.3001617
#  val_penalty:0.3494553
#  euler_penalty:4.2888107
#  total:0.1600788
# Measure Epoch 4083, train
#  similarity:0.1178387
#  penlog:-17.1217450
# Metrics Epoch 4083, train
#  batch_molecular_validity:8.0000000
#  batch_correctness:0.0000000
#  batch_symbol_accuracy:100.0000000
#  batch_molecular_disconnected_validity:84.0000000
#  batch_connected_components:5.9600000
#  batch_invalid_valency_nodes:1.4782609
#  batch_nodes_0degree:0.1600000
#  batch_nodes_7plus_degree:0.0200000
#  invalid_euler_toofew:82.0000000
#  invalid_euler_toomany:0.0000000
#  avg_euler_error:-5.0800000
#  batch_node_degree:2.2017391
# Epoch 4084
# train_0.out
# fgw 0.16062389373779296
# conn_penalty 0.353154296875
# val_penalty 0.40301525115966796
# euler_penalty 4.110060119628907
# total 0.1659063720703125
# Losses Epoch 4084, train
#  fgw:0.1606239
#  conn_penalty:0.3531543
#  val_penalty:0.4030153
#  euler_penalty:4.1100601
#  total:0.1659064
# Measure Epoch 4084, train
#  similarity:0.1275621
#  penlog:-16.4126875
# Metrics Epoch 4084, train
#  batch_molecular_validity:10.0000000
#  batch_correctness:0.0000000
#  batch_symbol_accuracy:100.0000000
#  batch_molecular_disconnected_validity:84.0000000
#  batch_connected_components:5.7400000
#  batch_invalid_valency_nodes:1.8260870
#  batch_nodes_0degree:0.1800000
#  batch_nodes_7plus_degree:0.0000000
#  invalid_euler_toofew:76.0000000
#  invalid_euler_toomany:0.0000000
#  avg_euler_error:-4.7800000
#  batch_node_degree:2.2278261
# Epoch 4085
# train_0.out
# fgw 0.15707656860351563
# conn_penalty 0.4776995849609375
# val_penalty 0.44422451019287107
# euler_penalty 4.1517578125
# total 0.16259035110473632
# Losses Epoch 4085, train
#  fgw:0.1570766
#  conn_penalty:0.4776996
#  val_penalty:0.4442245
#  euler_penalty:4.1517578
#  total:0.1625904
# Measure Epoch 4085, train
#  similarity:0.1256137
#  penlog:-18.3350335
# Metrics Epoch 4085, train
#  batch_molecular_validity:10.0000000
#  batch_correctness:0.0000000
#  batch_symbol_accuracy:100.0000000
#  batch_molecular_disconnected_validity:82.0000000
#  batch_connected_components:5.9000000
#  batch_invalid_valency_nodes:2.0000000
#  batch_nodes_0degree:0.2800000
#  batch_nodes_7plus_degree:0.0000000
#  invalid_euler_toofew:80.0000000
#  invalid_euler_toomany:0.0000000
#  avg_euler_error:-4.9800000
#  batch_node_degree:2.2017391
# Epoch 4086
# train_0.out
# fgw 0.15901782989501953
# conn_penalty 0.5244461059570312
# val_penalty 0.4233388900756836
# euler_penalty 4.182839050292968
# total 0.16459901809692382
# Losses Epoch 4086, train
#  fgw:0.1590178
#  conn_penalty:0.5244461
#  val_penalty:0.4233389
#  euler_penalty:4.1828391
#  total:0.1645990
# Measure Epoch 4086, train
#  similarity:0.1192610
#  penlog:-18.3398707
# Metrics Epoch 4086, train
#  batch_molecular_validity:8.0000000
#  batch_correctness:0.0000000
#  batch_symbol_accuracy:100.0000000
#  batch_molecular_disconnected_validity:82.0000000
#  batch_connected_components:5.8800000
#  batch_invalid_valency_nodes:2.0000000
#  batch_nodes_0degree:0.2400000
#  batch_nodes_7plus_degree:0.0000000
#  invalid_euler_toofew:74.0000000
#  invalid_euler_toomany:0.0000000
#  avg_euler_error:-4.9600000
#  batch_node_degree:2.2069565
# Epoch 4087
# train_0.out
# fgw 0.15487634658813476
# conn_penalty 0.3637020874023438
# val_penalty 0.3658962631225586
# euler_penalty 4.29640625
# total 0.1603482437133789
# Losses Epoch 4087, train
#  fgw:0.1548763
#  conn_penalty:0.3637021
#  val_penalty:0.3658963
#  euler_penalty:4.2964063
#  total:0.1603482
# Measure Epoch 4087, train
#  similarity:0.1222802
#  penlog:-14.4143707
# Metrics Epoch 4087, train
#  batch_molecular_validity:8.0000000
#  batch_correctness:0.0000000
#  batch_symbol_accuracy:100.0000000
#  batch_molecular_disconnected_validity:86.0000000
#  batch_connected_components:6.0600000
#  batch_invalid_valency_nodes:1.7391304
#  batch_nodes_0degree:0.2000000
#  batch_nodes_7plus_degree:0.0000000
#  invalid_euler_toofew:78.0000000
#  invalid_euler_toomany:0.0000000
#  avg_euler_error:-5.1400000
#  batch_node_degree:2.1965217
# Epoch 4088
# train_0.out
# fgw 0.15161992073059083
# conn_penalty 0.2577265930175781
# val_penalty 0.34318443298339846
# euler_penalty 4.205897521972656
# total 0.15685800552368165
# Losses Epoch 4088, train
#  fgw:0.1516199
#  conn_penalty:0.2577266
#  val_penalty:0.3431844
#  euler_penalty:4.2058975
#  total:0.1568580
# Measure Epoch 4088, train
#  similarity:0.1171387
#  penlog:-12.4361497
# Metrics Epoch 4088, train
#  batch_molecular_validity:6.0000000
#  batch_correctness:0.0000000
#  batch_symbol_accuracy:100.0000000
#  batch_molecular_disconnected_validity:88.0000000
#  batch_connected_components:5.9400000
#  batch_invalid_valency_nodes:1.4782609
#  batch_nodes_0degree:0.1600000
#  batch_nodes_7plus_degree:0.0000000
#  invalid_euler_toofew:86.0000000
#  invalid_euler_toomany:0.0000000
#  avg_euler_error:-5.0200000
#  batch_node_degree:2.2086957
# Epoch 4089
# train_0.out
# fgw 0.15787042617797853
# conn_penalty 0.14465850830078125
# val_penalty 0.41001110076904296
# euler_penalty 3.898375244140625
# total 0.16272829055786134
# Losses Epoch 4089, train
#  fgw:0.1578704
#  conn_penalty:0.1446585
#  val_penalty:0.4100111
#  euler_penalty:3.8983752
#  total:0.1627283
# Measure Epoch 4089, train
#  similarity:0.1039989
#  penlog:-26.3369569
# Metrics Epoch 4089, train
#  batch_molecular_validity:8.0000000
#  batch_correctness:0.0000000
#  batch_symbol_accuracy:100.0000000
#  batch_molecular_disconnected_validity:74.0000000
#  batch_connected_components:5.7600000
#  batch_invalid_valency_nodes:2.0000000
#  batch_nodes_0degree:0.1600000
#  batch_nodes_7plus_degree:0.0000000
#  invalid_euler_toofew:76.0000000
#  invalid_euler_toomany:0.0000000
#  avg_euler_error:-4.7600000
#  batch_node_degree:2.2278261
# Epoch 4090
# train_0.out
# fgw 0.15505815505981446
# conn_penalty 0.32140090942382815
# val_penalty 0.32067764282226563
# euler_penalty 4.105751037597656
# total 0.16024240493774414
# Losses Epoch 4090, train
#  fgw:0.1550582
#  conn_penalty:0.3214009
#  val_penalty:0.3206776
#  euler_penalty:4.1057510
#  total:0.1602424
# Measure Epoch 4090, train
#  similarity:0.1226776
#  penlog:-18.5228022
# Metrics Epoch 4090, train
#  batch_molecular_validity:8.0000000
#  batch_correctness:0.0000000
#  batch_symbol_accuracy:100.0000000
#  batch_molecular_disconnected_validity:82.0000000
#  batch_connected_components:5.8200000
#  batch_invalid_valency_nodes:1.3913043
#  batch_nodes_0degree:0.1200000
#  batch_nodes_7plus_degree:0.0000000
#  invalid_euler_toofew:78.0000000
#  invalid_euler_toomany:0.0000000
#  avg_euler_error:-4.9200000
#  batch_node_degree:2.2121739
# Epoch 4091
# train_0.out
# fgw 0.1476627540588379
# conn_penalty 0.4175372314453125
# val_penalty 0.2575112915039062
# euler_penalty 4.1949224853515625
# total 0.1529854106903076
# Losses Epoch 4091, train
#  fgw:0.1476628
#  conn_penalty:0.4175372
#  val_penalty:0.2575113
#  euler_penalty:4.1949225
#  total:0.1529854
# Measure Epoch 4091, train
#  similarity:0.1255737
#  penlog:-14.8095696
# Metrics Epoch 4091, train
#  batch_molecular_validity:8.0000000
#  batch_correctness:0.0000000
#  batch_symbol_accuracy:100.0000000
#  batch_molecular_disconnected_validity:86.0000000
#  batch_connected_components:5.8200000
#  batch_invalid_valency_nodes:1.1304348
#  batch_nodes_0degree:0.1200000
#  batch_nodes_7plus_degree:0.0000000
#  invalid_euler_toofew:80.0000000
#  invalid_euler_toomany:0.0000000
#  avg_euler_error:-5.0000000
#  batch_node_degree:2.2052174
# Epoch 4092
# train_0.out
# fgw 0.156696138381958
# conn_penalty 0.27756500244140625
# val_penalty 0.33120265960693357
# euler_penalty 3.8548431396484375
# total 0.16157997131347657
# Losses Epoch 4092, train
#  fgw:0.1566961
#  conn_penalty:0.2775650
#  val_penalty:0.3312027
#  euler_penalty:3.8548431
#  total:0.1615800
# Measure Epoch 4092, train
#  similarity:0.1171437
#  penlog:-20.9261894
# Metrics Epoch 4092, train
#  batch_molecular_validity:10.0000000
#  batch_correctness:0.0000000
#  batch_symbol_accuracy:100.0000000
#  batch_molecular_disconnected_validity:80.0000000
#  batch_connected_components:5.7000000
#  batch_invalid_valency_nodes:1.2173913
#  batch_nodes_0degree:0.0800000
#  batch_nodes_7plus_degree:0.0200000
#  invalid_euler_toofew:74.0000000
#  invalid_euler_toomany:0.0000000
#  avg_euler_error:-4.7400000
#  batch_node_degree:2.2313043
# Epoch 4093
# train_0.out
# fgw 0.15428356170654298
# conn_penalty 0.27842178344726565
# val_penalty 0.36308467864990235
# euler_penalty 3.8067861938476564
# total 0.15915581703186035
# Losses Epoch 4093, train
#  fgw:0.1542836
#  conn_penalty:0.2784218
#  val_penalty:0.3630847
#  euler_penalty:3.8067862
#  total:0.1591558
# Measure Epoch 4093, train
#  similarity:0.1039799
#  penlog:-26.9379163
# Metrics Epoch 4093, train
#  batch_molecular_validity:8.0000000
#  batch_correctness:0.0000000
#  batch_symbol_accuracy:100.0000000
#  batch_molecular_disconnected_validity:74.0000000
#  batch_connected_components:5.5800000
#  batch_invalid_valency_nodes:1.5652174
#  batch_nodes_0degree:0.1000000
#  batch_nodes_7plus_degree:0.0200000
#  invalid_euler_toofew:74.0000000
#  invalid_euler_toomany:0.0000000
#  avg_euler_error:-4.5600000
#  batch_node_degree:2.2469565
# Epoch 4094
# train_0.out
# fgw 0.16085124969482423
# conn_penalty 0.36748077392578127
# val_penalty 0.37005111694335935
# euler_penalty 3.8677691650390624
# total 0.16590078353881835
# Losses Epoch 4094, train
#  fgw:0.1608512
#  conn_penalty:0.3674808
#  val_penalty:0.3700511
#  euler_penalty:3.8677692
#  total:0.1659008
# Measure Epoch 4094, train
#  similarity:0.1034249
#  penlog:-24.9835507
# Metrics Epoch 4094, train
#  batch_molecular_validity:8.0000000
#  batch_correctness:0.0000000
#  batch_symbol_accuracy:100.0000000
#  batch_molecular_disconnected_validity:76.0000000
#  batch_connected_components:5.6000000
#  batch_invalid_valency_nodes:1.6521739
#  batch_nodes_0degree:0.1200000
#  batch_nodes_7plus_degree:0.0200000
#  invalid_euler_toofew:72.0000000
#  invalid_euler_toomany:0.0000000
#  avg_euler_error:-4.6400000
#  batch_node_degree:2.2434783
# Epoch 4095
# train_0.out
# fgw 0.15719380378723144
# conn_penalty 0.30425827026367186
# val_penalty 0.4213112258911133
# euler_penalty 3.7296823120117186
# total 0.16208410263061523
# Losses Epoch 4095, train
#  fgw:0.1571938
#  conn_penalty:0.3042583
#  val_penalty:0.4213112
#  euler_penalty:3.7296823
#  total:0.1620841
# Measure Epoch 4095, train
#  similarity:0.1129349
#  penlog:-25.0839175
# Metrics Epoch 4095, train
#  batch_molecular_validity:8.0000000
#  batch_correctness:0.0000000
#  batch_symbol_accuracy:100.0000000
#  batch_molecular_disconnected_validity:76.0000000
#  batch_connected_components:5.5800000
#  batch_invalid_valency_nodes:1.9130435
#  batch_nodes_0degree:0.1600000
#  batch_nodes_7plus_degree:0.0000000
#  invalid_euler_toofew:74.0000000
#  invalid_euler_toomany:0.0000000
#  avg_euler_error:-4.6200000
#  batch_node_degree:2.2434783
# Epoch 4096
# train_0.out
# fgw 0.15677403450012206
# conn_penalty 0.2698661804199219
# val_penalty 0.3803119277954102
# euler_penalty 3.7819247436523438
# total 0.16164329528808594
# Losses Epoch 4096, train
#  fgw:0.1567740
#  conn_penalty:0.2698662
#  val_penalty:0.3803119
#  euler_penalty:3.7819247
#  total:0.1616433
# Measure Epoch 4096, train
#  similarity:0.1153036
#  penlog:-23.3481337
# Metrics Epoch 4096, train
#  batch_molecular_validity:6.0000000
#  batch_correctness:0.0000000
#  batch_symbol_accuracy:100.0000000
#  batch_molecular_disconnected_validity:78.0000000
#  batch_connected_components:5.4800000
#  batch_invalid_valency_nodes:1.6521739
#  batch_nodes_0degree:0.1200000
#  batch_nodes_7plus_degree:0.0000000
#  invalid_euler_toofew:70.0000000
#  invalid_euler_toomany:0.0000000
#  avg_euler_error:-4.5200000
#  batch_node_degree:2.2521739
# Epoch 4097
# train_0.out
# fgw 0.16119306564331054
# conn_penalty 0.25296722412109374
# val_penalty 0.2990156936645508
# euler_penalty 3.909961853027344
# total 0.16609912872314453
# Losses Epoch 4097, train
#  fgw:0.1611931
#  conn_penalty:0.2529672
#  val_penalty:0.2990157
#  euler_penalty:3.9099619
#  total:0.1660991
# Measure Epoch 4097, train
#  similarity:0.1216766
#  penlog:-14.6608329
# Metrics Epoch 4097, train
#  batch_molecular_validity:6.0000000
#  batch_correctness:0.0000000
#  batch_symbol_accuracy:100.0000000
#  batch_molecular_disconnected_validity:86.0000000
#  batch_connected_components:5.7000000
#  batch_invalid_valency_nodes:1.3913043
#  batch_nodes_0degree:0.1400000
#  batch_nodes_7plus_degree:0.0000000
#  invalid_euler_toofew:78.0000000
#  invalid_euler_toomany:0.0000000
#  avg_euler_error:-4.8400000
#  batch_node_degree:2.2243478
# Epoch 4098
# train_0.out
# fgw 0.15999116897583007
# conn_penalty 0.21862014770507812
# val_penalty 0.2718595314025879
# euler_penalty 3.878675537109375
# total 0.1647996711730957
# Losses Epoch 4098, train
#  fgw:0.1599912
#  conn_penalty:0.2186201
#  val_penalty:0.2718595
#  euler_penalty:3.8786755
#  total:0.1647997
# Measure Epoch 4098, train
#  similarity:0.1203684
#  penlog:-12.7434952
# Metrics Epoch 4098, train
#  batch_molecular_validity:6.0000000
#  batch_correctness:0.0000000
#  batch_symbol_accuracy:100.0000000
#  batch_molecular_disconnected_validity:88.0000000
#  batch_connected_components:5.6200000
#  batch_invalid_valency_nodes:1.3913043
#  batch_nodes_0degree:0.1400000
#  batch_nodes_7plus_degree:0.0000000
#  invalid_euler_toofew:74.0000000
#  invalid_euler_toomany:0.0000000
#  avg_euler_error:-4.6800000
#  batch_node_degree:2.2382609
# Epoch 4099
# train_0.out
# fgw 0.15550626754760744
# conn_penalty 0.15324050903320313
# val_penalty 0.3169990539550781
# euler_penalty 3.7221539306640623
# total 0.16012516021728515
# Losses Epoch 4099, train
#  fgw:0.1555063
#  conn_penalty:0.1532405
#  val_penalty:0.3169991
#  euler_penalty:3.7221539
#  total:0.1601252
# Measure Epoch 4099, train
#  similarity:0.1244493
#  penlog:-16.2562333
# Metrics Epoch 4099, train
#  batch_molecular_validity:6.0000000
#  batch_correctness:0.0000000
#  batch_symbol_accuracy:100.0000000
#  batch_molecular_disconnected_validity:84.0000000
#  batch_connected_components:5.4200000
#  batch_invalid_valency_nodes:1.8260870
#  batch_nodes_0degree:0.1600000
#  batch_nodes_7plus_degree:0.0000000
#  invalid_euler_toofew:70.0000000
#  invalid_euler_toomany:0.0000000
#  avg_euler_error:-4.4000000
#  batch_node_degree:2.2573913
# Epoch 4100
# train_0.out
# fgw 0.15874247550964354
# conn_penalty 0.25407440185546876
# val_penalty 0.22955984115600586
# euler_penalty 4.109854125976563
# total 0.16380752563476564
# Losses Epoch 4100, train
#  fgw:0.1587425
#  conn_penalty:0.2540744
#  val_penalty:0.2295598
#  euler_penalty:4.1098541
#  total:0.1638075
# Measure Epoch 4100, train
#  similarity:0.1254137
#  penlog:-12.4202332
# Metrics Epoch 4100, train
#  batch_molecular_validity:6.0000000
#  batch_correctness:0.0000000
#  batch_symbol_accuracy:100.0000000
#  batch_molecular_disconnected_validity:88.0000000
#  batch_connected_components:5.7200000
#  batch_invalid_valency_nodes:1.0434783
#  batch_nodes_0degree:0.1200000
#  batch_nodes_7plus_degree:0.0000000
#  invalid_euler_toofew:82.0000000
#  invalid_euler_toomany:0.0000000
#  avg_euler_error:-4.9200000
#  batch_node_degree:2.2156522
# Epoch 4101
# train_0.out
# fgw 0.16985715866088869
# conn_penalty 0.17418487548828124
# val_penalty 0.2798627281188965
# euler_penalty 3.9174185180664063
# total 0.1746825408935547
# Losses Epoch 4101, train
#  fgw:0.1698572
#  conn_penalty:0.1741849
#  val_penalty:0.2798627
#  euler_penalty:3.9174185
#  total:0.1746825
# Measure Epoch 4101, train
#  similarity:0.1157429
#  penlog:-16.3161884
# Metrics Epoch 4101, train
#  batch_molecular_validity:8.0000000
#  batch_correctness:0.0000000
#  batch_symbol_accuracy:100.0000000
#  batch_molecular_disconnected_validity:84.0000000
#  batch_connected_components:5.5200000
#  batch_invalid_valency_nodes:1.3913043
#  batch_nodes_0degree:0.1200000
#  batch_nodes_7plus_degree:0.0200000
#  invalid_euler_toofew:78.0000000
#  invalid_euler_toomany:0.0000000
#  avg_euler_error:-4.6800000
#  batch_node_degree:2.2347826
# Epoch 4102
# train_0.out
# fgw 0.16027618408203126
# conn_penalty 0.11497665405273437
# val_penalty 0.33042102813720703
# euler_penalty 3.7100039672851564
# total 0.16486806869506837
# Losses Epoch 4102, train
#  fgw:0.1602762
#  conn_penalty:0.1149767
#  val_penalty:0.3304210
#  euler_penalty:3.7100040
#  total:0.1648681
# Measure Epoch 4102, train
#  similarity:0.1236380
#  penlog:-14.7713531
# Metrics Epoch 4102, train
#  batch_molecular_validity:14.0000000
#  batch_correctness:0.0000000
#  batch_symbol_accuracy:100.0000000
#  batch_molecular_disconnected_validity:86.0000000
#  batch_connected_components:5.3600000
#  batch_invalid_valency_nodes:1.1304348
#  batch_nodes_0degree:0.1000000
#  batch_nodes_7plus_degree:0.0000000
#  invalid_euler_toofew:74.0000000
#  invalid_euler_toomany:0.0000000
#  avg_euler_error:-4.4400000
#  batch_node_degree:2.2504348
# Epoch 4103
# train_0.out
# fgw 0.16925636291503907
# conn_penalty 0.16286590576171875
# val_penalty 0.25568037033081054
# euler_penalty 3.9565414428710937
# total 0.17409507751464845
# Losses Epoch 4103, train
#  fgw:0.1692564
#  conn_penalty:0.1628659
#  val_penalty:0.2556804
#  euler_penalty:3.9565414
#  total:0.1740951
# Measure Epoch 4103, train
#  similarity:0.1142523
#  penlog:-12.6340303
# Metrics Epoch 4103, train
#  batch_molecular_validity:8.0000000
#  batch_correctness:0.0000000
#  batch_symbol_accuracy:100.0000000
#  batch_molecular_disconnected_validity:88.0000000
#  batch_connected_components:5.5000000
#  batch_invalid_valency_nodes:1.0434783
#  batch_nodes_0degree:0.1200000
#  batch_nodes_7plus_degree:0.0000000
#  invalid_euler_toofew:84.0000000
#  invalid_euler_toomany:0.0000000
#  avg_euler_error:-4.8200000
#  batch_node_degree:2.2156522
# Epoch 4104
# train_0.out
# fgw 0.15722373962402345
# conn_penalty 0.17077377319335937
# val_penalty 0.20042591094970702
# euler_penalty 3.9946710205078126
# total 0.1620565414428711
# Losses Epoch 4104, train
#  fgw:0.1572237
#  conn_penalty:0.1707738
#  val_penalty:0.2004259
#  euler_penalty:3.9946710
#  total:0.1620565
# Measure Epoch 4104, train
#  similarity:0.1204841
#  penlog:-10.7330629
# Metrics Epoch 4104, train
#  batch_molecular_validity:8.0000000
#  batch_correctness:0.0000000
#  batch_symbol_accuracy:100.0000000
#  batch_molecular_disconnected_validity:90.0000000
#  batch_connected_components:5.5200000
#  batch_invalid_valency_nodes:0.8695652
#  batch_nodes_0degree:0.1000000
#  batch_nodes_7plus_degree:0.0000000
#  invalid_euler_toofew:82.0000000
#  invalid_euler_toomany:0.0000000
#  avg_euler_error:-4.7200000
#  batch_node_degree:2.2260870
# Epoch 4105
# train_0.out
# fgw 0.16084203720092774
# conn_penalty 0.1511285400390625
# val_penalty 0.2482275390625
# euler_penalty 3.7526315307617186
# total 0.16544322967529296
# Losses Epoch 4105, train
#  fgw:0.1608420
#  conn_penalty:0.1511285
#  val_penalty:0.2482275
#  euler_penalty:3.7526315
#  total:0.1654432
# Measure Epoch 4105, train
#  similarity:0.1349173
#  penlog:-12.2665799
# Metrics Epoch 4105, train
#  batch_molecular_validity:8.0000000
#  batch_correctness:0.0000000
#  batch_symbol_accuracy:100.0000000
#  batch_molecular_disconnected_validity:88.0000000
#  batch_connected_components:5.3800000
#  batch_invalid_valency_nodes:1.0434783
#  batch_nodes_0degree:0.1000000
#  batch_nodes_7plus_degree:0.0000000
#  invalid_euler_toofew:78.0000000
#  invalid_euler_toomany:0.0000000
#  avg_euler_error:-4.4400000
#  batch_node_degree:2.2486957
# Epoch 4106
# train_0.out
# fgw 0.15759307861328126
# conn_penalty 0.3014141845703125
# val_penalty 0.20977239608764647
# euler_penalty 3.960987854003906
# total 0.1625540542602539
# Losses Epoch 4106, train
#  fgw:0.1575931
#  conn_penalty:0.3014142
#  val_penalty:0.2097724
#  euler_penalty:3.9609879
#  total:0.1625541
# Measure Epoch 4106, train
#  similarity:0.1555904
#  penlog:-7.1136193
# Metrics Epoch 4106, train
#  batch_molecular_validity:10.0000000
#  batch_correctness:0.0000000
#  batch_symbol_accuracy:100.0000000
#  batch_molecular_disconnected_validity:94.0000000
#  batch_connected_components:5.5600000
#  batch_invalid_valency_nodes:0.8695652
#  batch_nodes_0degree:0.1400000
#  batch_nodes_7plus_degree:0.0000000
#  invalid_euler_toofew:78.0000000
#  invalid_euler_toomany:0.0000000
#  avg_euler_error:-4.7600000
#  batch_node_degree:2.2191304
# Epoch 4107
# train_0.out
# fgw 0.15276576995849608
# conn_penalty 0.2778665161132812
# val_penalty 0.2248202896118164
# euler_penalty 3.9316510009765624
# total 0.15768977165222167
# Losses Epoch 4107, train
#  fgw:0.1527658
#  conn_penalty:0.2778665
#  val_penalty:0.2248203
#  euler_penalty:3.9316510
#  total:0.1576898
# Measure Epoch 4107, train
#  similarity:0.1471964
#  penlog:-16.7809987
# Metrics Epoch 4107, train
#  batch_molecular_validity:10.0000000
#  batch_correctness:0.0000000
#  batch_symbol_accuracy:100.0000000
#  batch_molecular_disconnected_validity:84.0000000
#  batch_connected_components:5.4800000
#  batch_invalid_valency_nodes:1.3043478
#  batch_nodes_0degree:0.1400000
#  batch_nodes_7plus_degree:0.0000000
#  invalid_euler_toofew:82.0000000
#  invalid_euler_toomany:0.0000000
#  avg_euler_error:-4.6800000
#  batch_node_degree:2.2260870
# Epoch 4108
# train_0.out
# fgw 0.15279070854187013
# conn_penalty 0.21137359619140625
# val_penalty 0.2554516410827637
# euler_penalty 3.7498129272460936
# total 0.15747783660888673
# Losses Epoch 4108, train
#  fgw:0.1527907
#  conn_penalty:0.2113736
#  val_penalty:0.2554516
#  euler_penalty:3.7498129
#  total:0.1574778
# Measure Epoch 4108, train
#  similarity:0.1419146
#  penlog:-20.7025743
# Metrics Epoch 4108, train
#  batch_molecular_validity:10.0000000
#  batch_correctness:0.0000000
#  batch_symbol_accuracy:100.0000000
#  batch_molecular_disconnected_validity:80.0000000
#  batch_connected_components:5.3400000
# ...
#  val_penalty:0.2319765
#  euler_penalty:0.5223346
#  total:0.1471495
# Measure Epoch 5394, train
#  similarity:0.1849015
#  penlog:-19.6696732
# Metrics Epoch 5394, train
#  batch_molecular_validity:28.0000000
#  batch_correctness:0.0000000
#  batch_symbol_accuracy:100.0000000
#  batch_molecular_disconnected_validity:82.0000000
#  batch_connected_components:2.0800000
#  batch_invalid_valency_nodes:0.9565217
#  batch_nodes_0degree:0.0200000
#  batch_nodes_7plus_degree:0.0200000
#  invalid_euler_toofew:26.0000000
#  invalid_euler_toomany:0.0000000
#  avg_euler_error:-0.8600000
#  batch_node_degree:2.5600000
# Epoch 5395
# train_0.out
# fgw 0.14670287132263182
# conn_penalty 0.04759796142578125
# val_penalty 0.1882624626159668
# euler_penalty 0.6444499206542968
# total 0.15031329154968262
# Losses Epoch 5395, train
#  fgw:0.1467029
#  conn_penalty:0.0475980
#  val_penalty:0.1882625
#  euler_penalty:0.6444499
#  total:0.1503133
# Measure Epoch 5395, train
#  similarity:0.1737082
#  penlog:-19.4549339
# Metrics Epoch 5395, train
#  batch_molecular_validity:26.0000000
#  batch_correctness:0.0000000
#  batch_symbol_accuracy:100.0000000
#  batch_molecular_disconnected_validity:82.0000000
#  batch_connected_components:2.1000000
#  batch_invalid_valency_nodes:0.9565217
#  batch_nodes_0degree:0.0200000
#  batch_nodes_7plus_degree:0.0200000
#  invalid_euler_toofew:26.0000000
#  invalid_euler_toomany:0.0000000
#  avg_euler_error:-0.9800000
#  batch_node_degree:2.5478261
# Epoch 5396
# train_0.out
# fgw 0.1405618095397949
# conn_penalty 0.0
# val_penalty 0.2902346611022949
# euler_penalty 0.32709522247314454
# total 0.14317423820495606
# Losses Epoch 5396, train
#  fgw:0.1405618
#  conn_penalty:0.0000000
#  val_penalty:0.2902347
#  euler_penalty:0.3270952
#  total:0.1431742
# Measure Epoch 5396, train
#  similarity:0.1990310
#  penlog:-23.6531648
# Metrics Epoch 5396, train
#  batch_molecular_validity:34.0000000
#  batch_correctness:0.0000000
#  batch_symbol_accuracy:100.0000000
#  batch_molecular_disconnected_validity:78.0000000
#  batch_connected_components:1.8800000
#  batch_invalid_valency_nodes:1.1304348
#  batch_nodes_0degree:0.0200000
#  batch_nodes_7plus_degree:0.0200000
#  invalid_euler_toofew:20.0000000
#  invalid_euler_toomany:0.0000000
#  avg_euler_error:-0.6000000
#  batch_node_degree:2.5808696
# Epoch 5397
# train_0.out
# fgw 0.14988818168640136
# conn_penalty 0.0103265380859375
# val_penalty 0.23989349365234375
# euler_penalty 0.39969879150390625
# total 0.15260812759399414
# Losses Epoch 5397, train
#  fgw:0.1498882
#  conn_penalty:0.0103265
#  val_penalty:0.2398935
#  euler_penalty:0.3996988
#  total:0.1526081
# Measure Epoch 5397, train
#  similarity:0.2070042
#  penlog:-21.5244941
# Metrics Epoch 5397, train
#  batch_molecular_validity:28.0000000
#  batch_correctness:0.0000000
#  batch_symbol_accuracy:100.0000000
#  batch_molecular_disconnected_validity:80.0000000
#  batch_connected_components:2.0200000
#  batch_invalid_valency_nodes:0.9565217
#  batch_nodes_0degree:0.0200000
#  batch_nodes_7plus_degree:0.0200000
#  invalid_euler_toofew:24.0000000
#  invalid_euler_toomany:0.0000000
#  avg_euler_error:-0.7600000
#  batch_node_degree:2.5686957
# Epoch 5398
# train_0.out
# fgw 0.15443264007568358
# conn_penalty 0.0896771240234375
# val_penalty 0.14899661064147948
# euler_penalty 0.8108245086669922
# total 0.15871667861938477
# Losses Epoch 5398, train
#  fgw:0.1544326
#  conn_penalty:0.0896771
#  val_penalty:0.1489966
#  euler_penalty:0.8108245
#  total:0.1587167
# Measure Epoch 5398, train
#  similarity:0.1877722
#  penlog:-11.4773218
# Metrics Epoch 5398, train
#  batch_molecular_validity:20.0000000
#  batch_correctness:0.0000000
#  batch_symbol_accuracy:100.0000000
#  batch_molecular_disconnected_validity:90.0000000
#  batch_connected_components:2.3600000
#  batch_invalid_valency_nodes:0.5217391
#  batch_nodes_0degree:0.0200000
#  batch_nodes_7plus_degree:0.0000000
#  invalid_euler_toofew:38.0000000
#  invalid_euler_toomany:0.0000000
#  avg_euler_error:-1.2600000
#  batch_node_degree:2.5252174
# Epoch 5399
# train_0.out
# fgw 0.1454549503326416
# conn_penalty 0.0
# val_penalty 0.34537166595458985
# euler_penalty 0.27052343368530274
# total 0.14809983253479003
# Losses Epoch 5399, train
#  fgw:0.1454550
#  conn_penalty:0.0000000
#  val_penalty:0.3453717
#  euler_penalty:0.2705234
#  total:0.1480998
# Measure Epoch 5399, train
#  similarity:0.2165233
#  penlog:-31.5086542
# Metrics Epoch 5399, train
#  batch_molecular_validity:38.0000000
#  batch_correctness:0.0000000
#  batch_symbol_accuracy:100.0000000
#  batch_molecular_disconnected_validity:70.0000000
#  batch_connected_components:1.7400000
#  batch_invalid_valency_nodes:1.4782609
#  batch_nodes_0degree:0.0200000
#  batch_nodes_7plus_degree:0.0000000
#  invalid_euler_toofew:16.0000000
#  invalid_euler_toomany:0.0000000
#  avg_euler_error:-0.3800000
#  batch_node_degree:2.6017391
# Epoch 5400
# train_0.out
# fgw 0.14697693824768066
# conn_penalty 0.0
# val_penalty 0.31442716598510745
# euler_penalty 0.3039670372009277
# total 0.14961767196655273
# Losses Epoch 5400, train
#  fgw:0.1469769
#  conn_penalty:0.0000000
#  val_penalty:0.3144272
#  euler_penalty:0.3039670
#  total:0.1496177
# Measure Epoch 5400, train
#  similarity:0.2076469
#  penlog:-33.5844332
# Metrics Epoch 5400, train
#  batch_molecular_validity:36.0000000
#  batch_correctness:0.0000000
#  batch_symbol_accuracy:100.0000000
#  batch_molecular_disconnected_validity:68.0000000
#  batch_connected_components:1.7200000
#  batch_invalid_valency_nodes:1.6521739
#  batch_nodes_0degree:0.0200000
#  batch_nodes_7plus_degree:0.0000000
#  invalid_euler_toofew:18.0000000
#  invalid_euler_toomany:0.0000000
#  avg_euler_error:-0.4200000
#  batch_node_degree:2.5982609
# Epoch 5401
# train_0.out
# fgw 0.1492360019683838
# conn_penalty 0.12244049072265625
# val_penalty 0.1359144115447998
# euler_penalty 1.1247368621826173
# total 0.15486681938171387
# Losses Epoch 5401, train
#  fgw:0.1492360
#  conn_penalty:0.1224405
#  val_penalty:0.1359144
#  euler_penalty:1.1247369
#  total:0.1548668
# Measure Epoch 5401, train
#  similarity:0.2012174
#  penlog:-11.3520585
# Metrics Epoch 5401, train
#  batch_molecular_validity:26.0000000
#  batch_correctness:0.0000000
#  batch_symbol_accuracy:100.0000000
#  batch_molecular_disconnected_validity:90.0000000
#  batch_connected_components:2.4400000
#  batch_invalid_valency_nodes:0.5217391
#  batch_nodes_0degree:0.0200000
#  batch_nodes_7plus_degree:0.0000000
#  invalid_euler_toofew:44.0000000
#  invalid_euler_toomany:0.0000000
#  avg_euler_error:-1.3800000
#  batch_node_degree:2.5147826
# Epoch 5402
# train_0.out
# fgw 0.1427495861053467
# conn_penalty 0.0
# val_penalty 0.32866592407226564
# euler_penalty 0.26405670166015627
# total 0.14530091285705565
# Losses Epoch 5402, train
#  fgw:0.1427496
#  conn_penalty:0.0000000
#  val_penalty:0.3286659
#  euler_penalty:0.2640567
#  total:0.1453009
# Measure Epoch 5402, train
#  similarity:0.2077688
#  penlog:-33.4605788
# Metrics Epoch 5402, train
#  batch_molecular_validity:40.0000000
#  batch_correctness:0.0000000
#  batch_symbol_accuracy:100.0000000
#  batch_molecular_disconnected_validity:68.0000000
#  batch_connected_components:1.7200000
#  batch_invalid_valency_nodes:1.5652174
#  batch_nodes_0degree:0.0200000
#  batch_nodes_7plus_degree:0.0000000
#  invalid_euler_toofew:22.0000000
#  invalid_euler_toomany:0.0000000
#  avg_euler_error:-0.4800000
#  batch_node_degree:2.5913043
# Epoch 5403
# train_0.out
# fgw 0.1482275676727295
# conn_penalty 0.0
# val_penalty 0.3881048583984375
# euler_penalty 0.19356714248657225
# total 0.15076991081237792
# Losses Epoch 5403, train
#  fgw:0.1482276
#  conn_penalty:0.0000000
#  val_penalty:0.3881049
#  euler_penalty:0.1935671
#  total:0.1507699
# Measure Epoch 5403, train
#  similarity:0.2072702
#  penlog:-37.4707481
# Metrics Epoch 5403, train
#  batch_molecular_validity:40.0000000
#  batch_correctness:0.0000000
#  batch_symbol_accuracy:100.0000000
#  batch_molecular_disconnected_validity:64.0000000
#  batch_connected_components:1.6200000
#  batch_invalid_valency_nodes:1.6521739
#  batch_nodes_0degree:0.0000000
#  batch_nodes_7plus_degree:0.0000000
#  invalid_euler_toofew:16.0000000
#  invalid_euler_toomany:0.0000000
#  avg_euler_error:-0.3400000
#  batch_node_degree:2.6034783
# Epoch 5404
# train_0.out
# fgw 0.1551383590698242
# conn_penalty 0.062484130859375
# val_penalty 0.14506402969360352
# euler_penalty 0.6369315719604492
# total 0.15861799240112304
# Losses Epoch 5404, train
#  fgw:0.1551384
#  conn_penalty:0.0624841
#  val_penalty:0.1450640
#  euler_penalty:0.6369316
#  total:0.1586180
# Measure Epoch 5404, train
#  similarity:0.2045874
#  penlog:-11.3938792
# Metrics Epoch 5404, train
#  batch_molecular_validity:30.0000000
#  batch_correctness:0.0000000
#  batch_symbol_accuracy:100.0000000
#  batch_molecular_disconnected_validity:90.0000000
#  batch_connected_components:2.1600000
#  batch_invalid_valency_nodes:0.4347826
#  batch_nodes_0degree:0.0000000
#  batch_nodes_7plus_degree:0.0000000
#  invalid_euler_toofew:32.0000000
#  invalid_euler_toomany:0.0000000
#  avg_euler_error:-1.0400000
#  batch_node_degree:2.5426087
# Epoch 5405
# train_0.out
# fgw 0.1466591739654541
# conn_penalty 0.03402816772460938
# val_penalty 0.09591403007507324
# euler_penalty 0.9564915466308593
# total 0.1510794734954834
# Losses Epoch 5405, train
#  fgw:0.1466592
#  conn_penalty:0.0340282
#  val_penalty:0.0959140
#  euler_penalty:0.9564915
#  total:0.1510795
# Measure Epoch 5405, train
#  similarity:0.2000568
#  penlog:-9.3014951
# Metrics Epoch 5405, train
#  batch_molecular_validity:24.0000000
#  batch_correctness:0.0000000
#  batch_symbol_accuracy:100.0000000
#  batch_molecular_disconnected_validity:92.0000000
#  batch_connected_components:2.3200000
#  batch_invalid_valency_nodes:0.3478261
#  batch_nodes_0degree:0.0000000
#  batch_nodes_7plus_degree:0.0000000
#  invalid_euler_toofew:40.0000000
#  invalid_euler_toomany:0.0000000
#  avg_euler_error:-1.3400000
#  batch_node_degree:2.5165217
# Epoch 5406
# train_0.out
# fgw 0.1411305522918701
# conn_penalty 0.0
# val_penalty 0.35939037322998046
# euler_penalty 0.21684431076049804
# total 0.143643274307251
# Losses Epoch 5406, train
#  fgw:0.1411306
#  conn_penalty:0.0000000
#  val_penalty:0.3593904
#  euler_penalty:0.2168443
#  total:0.1436433
# Measure Epoch 5406, train
#  similarity:0.1761333
#  penlog:-31.2857239
# Metrics Epoch 5406, train
#  batch_molecular_validity:42.0000000
#  batch_correctness:0.0000000
#  batch_symbol_accuracy:100.0000000
#  batch_molecular_disconnected_validity:70.0000000
#  batch_connected_components:1.6000000
#  batch_invalid_valency_nodes:1.4782609
#  batch_nodes_0degree:0.0000000
#  batch_nodes_7plus_degree:0.0000000
#  invalid_euler_toofew:14.0000000
#  invalid_euler_toomany:0.0000000
#  avg_euler_error:-0.3800000
#  batch_node_degree:2.6000000
# Epoch 5407
# train_0.out
# fgw 0.13757827758789062
# conn_penalty 0.0
# val_penalty 0.4317771530151367
# euler_penalty 0.1597569179534912
# total 0.14019514083862306
# Losses Epoch 5407, train
#  fgw:0.1375783
#  conn_penalty:0.0000000
#  val_penalty:0.4317772
#  euler_penalty:0.1597569
#  total:0.1401951
# Measure Epoch 5407, train
#  similarity:0.1743101
#  penlog:-31.2920115
# Metrics Epoch 5407, train
#  batch_molecular_validity:42.0000000
#  batch_correctness:0.0000000
#  batch_symbol_accuracy:100.0000000
#  batch_molecular_disconnected_validity:70.0000000
#  batch_connected_components:1.5200000
#  batch_invalid_valency_nodes:1.7391304
#  batch_nodes_0degree:0.0000000
#  batch_nodes_7plus_degree:0.0000000
#  invalid_euler_toofew:8.0000000
#  invalid_euler_toomany:0.0000000
#  avg_euler_error:-0.3000000
#  batch_node_degree:2.6069565
# Epoch 5408
# train_0.out
# fgw 0.14684925079345704
# conn_penalty 0.1431158447265625
# val_penalty 0.21176513671875
# euler_penalty 0.517261962890625
# total 0.15051027297973632
# Losses Epoch 5408, train
#  fgw:0.1468493
#  conn_penalty:0.1431158
#  val_penalty:0.2117651
#  euler_penalty:0.5172620
#  total:0.1505103
# Measure Epoch 5408, train
#  similarity:0.2038083
#  penlog:-15.4089433
# Metrics Epoch 5408, train
#  batch_molecular_validity:30.0000000
#  batch_correctness:0.0000000
#  batch_symbol_accuracy:100.0000000
#  batch_molecular_disconnected_validity:86.0000000
#  batch_connected_components:2.0000000
#  batch_invalid_valency_nodes:0.9565217
#  batch_nodes_0degree:0.0200000
#  batch_nodes_7plus_degree:0.0000000
#  invalid_euler_toofew:26.0000000
#  invalid_euler_toomany:0.0000000
#  avg_euler_error:-0.8200000
#  batch_node_degree:2.5600000
# Epoch 5409
# train_0.out
# fgw 0.14563478469848634
# conn_penalty 0.09096710205078125
# val_penalty 0.12224268913269043
# euler_penalty 0.9662694549560547
# total 0.15047572135925294
# Losses Epoch 5409, train
#  fgw:0.1456348
#  conn_penalty:0.0909671
#  val_penalty:0.1222427
#  euler_penalty:0.9662695
#  total:0.1504757
# Measure Epoch 5409, train
#  similarity:0.2024354
#  penlog:-11.3091248
# Metrics Epoch 5409, train
#  batch_molecular_validity:22.0000000
#  batch_correctness:0.0000000
#  batch_symbol_accuracy:100.0000000
#  batch_molecular_disconnected_validity:90.0000000
#  batch_connected_components:2.3600000
#  batch_invalid_valency_nodes:0.4347826
#  batch_nodes_0degree:0.0000000
#  batch_nodes_7plus_degree:0.0000000
#  invalid_euler_toofew:42.0000000
#  invalid_euler_toomany:0.0000000
#  avg_euler_error:-1.2600000
#  batch_node_degree:2.5252174
# Epoch 5410
# train_0.out
# fgw 0.14396644592285157
# conn_penalty 0.0
# val_penalty 0.4835581970214844
# euler_penalty 0.21602407455444336
# total 0.14705610275268555
# Losses Epoch 5410, train
#  fgw:0.1439664
#  conn_penalty:0.0000000
#  val_penalty:0.4835582
#  euler_penalty:0.2160241
#  total:0.1470561
# Measure Epoch 5410, train
#  similarity:0.1761284
#  penlog:-35.3044266
# Metrics Epoch 5410, train
#  batch_molecular_validity:38.0000000
#  batch_correctness:0.0000000
#  batch_symbol_accuracy:100.0000000
#  batch_molecular_disconnected_validity:66.0000000
#  batch_connected_components:1.6400000
#  batch_invalid_valency_nodes:1.7391304
#  batch_nodes_0degree:0.0000000
#  batch_nodes_7plus_degree:0.0000000
#  invalid_euler_toofew:16.0000000
#  invalid_euler_toomany:0.0000000
#  avg_euler_error:-0.2000000
#  batch_node_degree:2.6208696
# Epoch 5411
# train_0.out
# fgw 0.15624240875244141
# conn_penalty 0.0
# val_penalty 0.45053451538085937
# euler_penalty 0.2678834915161133
# total 0.1593929958343506
# Losses Epoch 5411, train
#  fgw:0.1562424
#  conn_penalty:0.0000000
#  val_penalty:0.4505345
#  euler_penalty:0.2678835
#  total:0.1593930
# Measure Epoch 5411, train
#  similarity:0.1836689
#  penlog:-31.3802406
# Metrics Epoch 5411, train
#  batch_molecular_validity:34.0000000
#  batch_correctness:0.0000000
#  batch_symbol_accuracy:100.0000000
#  batch_molecular_disconnected_validity:70.0000000
#  batch_connected_components:1.7000000
#  batch_invalid_valency_nodes:1.3913043
#  batch_nodes_0degree:0.0000000
#  batch_nodes_7plus_degree:0.0000000
#  invalid_euler_toofew:22.0000000
#  invalid_euler_toomany:0.0000000
#  avg_euler_error:-0.3000000
#  batch_node_degree:2.6104348
# Epoch 5412
# train_0.out
# fgw 0.1465854549407959
# conn_penalty 0.0674346923828125
# val_penalty 0.14869562149047852
# euler_penalty 0.8216341400146484
# total 0.15087753295898437
# Losses Epoch 5412, train
#  fgw:0.1465855
#  conn_penalty:0.0674347
#  val_penalty:0.1486956
#  euler_penalty:0.8216341
#  total:0.1508775
# Measure Epoch 5412, train
#  similarity:0.2019739
#  penlog:-13.2933522
# Metrics Epoch 5412, train
#  batch_molecular_validity:28.0000000
#  batch_correctness:0.0000000
#  batch_symbol_accuracy:100.0000000
#  batch_molecular_disconnected_validity:88.0000000
#  batch_connected_components:2.2400000
#  batch_invalid_valency_nodes:0.6956522
#  batch_nodes_0degree:0.0200000
#  batch_nodes_7plus_degree:0.0000000
#  invalid_euler_toofew:34.0000000
#  invalid_euler_toomany:0.0000000
#  avg_euler_error:-1.0200000
#  batch_node_degree:2.5460870
# Epoch 5413
# train_0.out
# fgw 0.15639653205871581
# conn_penalty 0.033460693359375
# val_penalty 0.10899500846862793
# euler_penalty 0.9167098236083985
# total 0.1607492446899414
# Losses Epoch 5413, train
#  fgw:0.1563965
#  conn_penalty:0.0334607
#  val_penalty:0.1089950
#  euler_penalty:0.9167098
#  total:0.1607492
# Measure Epoch 5413, train
#  similarity:0.2260156
#  penlog:-11.2351913
# Metrics Epoch 5413, train
#  batch_molecular_validity:20.0000000
#  batch_correctness:0.0000000
#  batch_symbol_accuracy:100.0000000
#  batch_molecular_disconnected_validity:90.0000000
#  batch_connected_components:2.4600000
#  batch_invalid_valency_nodes:0.5217391
#  batch_nodes_0degree:0.0200000
#  batch_nodes_7plus_degree:0.0000000
#  invalid_euler_toofew:40.0000000
#  invalid_euler_toomany:0.0000000
#  avg_euler_error:-1.3000000
#  batch_node_degree:2.5200000
# Epoch 5414
# train_0.out
# fgw 0.14446104049682618
# conn_penalty 0.0
# val_penalty 0.3131216812133789
# euler_penalty 0.2705812454223633
# total 0.1469993209838867
