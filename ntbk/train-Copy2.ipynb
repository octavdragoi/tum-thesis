# %%
import os
if "ntbk" in os.getcwd():
    os.chdir("..")
print(os.getcwd())

import sys
sys.path.append(os.path.join(os.getcwd(), "otgnn"))


# %load_ext autoreload
# %autoreload 2

from otgnn.models import GCN
from otgnn.graph import MolGraph
from otgnn.utils import save_model, load_model

from mol_opt.data_mol_opt import MolOptDataset
from mol_opt.data_mol_opt import get_loader
from mol_opt.arguments import get_args
from mol_opt.train_mol_opt import main, get_latest_model
from mol_opt.ot_utils import compute_barycenter

from rdkit.Chem import MolFromSmiles

import torch
import numpy as np
import time
# Out:
# /home/octav/gitrepos/tum-thesis

# %%
sys.argv = ["", "-cuda", "-pred_hidden", "150", "-model_type", "slot"]
args = get_args()
args.n_epochs = 40 
args.init_model = "slot10"
args.output_dir = "mol_opt/output_{}".format(args.init_model)
args.tb_logs_dir = "mol_opt/logs_{}".format(args.init_model)
args.init_decoder_model = "{}_decode".format(args.init_model)
args
# Out:
# Namespace(N_transformer=6, agg_func='sum', annealing_rate=0.05, batch_norm=False, connectivity=True, connectivity_hard=False, connectivity_lambda=0.025, cuda=True, device='cuda:0', dim_tangent_space=40, dropout_ffn=0.0, dropout_gcn=0.0, dropout_transformer=0.1, euler_characteristic_penalty=True, euler_lambda=0.3, ffn_activation='LeakyReLU', init_decoder_model='slot10_decode', init_model='slot10', linear_out=False, model_type='slot', n_epochs=40, n_ffn_hidden=100, n_ffn_transformer=100, n_heads_transformer=10, n_hidden=50, n_labels=1, n_layers=5, ot_solver='emd', output_dir='mol_opt/output_slot10', pc_hidden=50, pred_hidden=150, sinkhorn_entropy=0.1, sinkhorn_max_it=10000, task='qed', tb_logs_dir='mol_opt/logs_slot10', valency=True, valency_hard=False, valency_lambda=0.07)

# %%
train_data_loader = get_loader("iclr19-graph2graph/data/qed", "train_pairs", 36, False)
val_data_loader = get_loader("iclr19-graph2graph/data/qed", "valid", 36, False)

# %%
molopt = main(args, train_data_loader = train_data_loader, val_data_loader = val_data_loader)
# Out:
# Epoch: 4
# idx_batch=0
#  train_fgw:1.0471050
#  train_conn_penalty:-0.3949307
#  train_val_penalty:0.0767688
#  train_euler_penalty:0.0345248
#  train_total:0.7634681
#  train_similarity:0.0017397
#  train_penlog:0.0000000
# idx_batch=400
#  train_fgw:0.8035856
#  train_conn_penalty:-0.4136974
#  train_val_penalty:0.0240594
#  train_euler_penalty:0.3173169
#  train_total:0.7312644
#  train_similarity:0.0003365
#  train_penlog:0.0000000
# idx_batch=800
#  train_fgw:0.8015772
#  train_conn_penalty:-0.4155738
#  train_val_penalty:0.0172917
#  train_euler_penalty:0.2855944
#  train_total:0.6888895
#  train_similarity:0.0002103
#  train_penlog:0.0000000
# idx_batch=1200
#  train_fgw:0.8009167
#  train_conn_penalty:-0.4153507
#  train_val_penalty:0.0155141
#  train_euler_penalty:0.2903450
#  train_total:0.6914251
#  train_similarity:0.0001971
#  train_penlog:0.0000000
#  train_molecular_disconnected_validity:100.0000000
#  train_molecular_validity:0.0000000
#  train_symbol_accuracy:0.0000000
#  train_connected_components:21.1666667
#  train_invalid_valency_nodes:0.0000000
# idx_batch=1600
#  train_fgw:0.8003822
#  train_conn_penalty:-0.4153298
#  train_val_penalty:0.0141591
#  train_euler_penalty:0.2923725
#  train_total:0.6915841
#  train_similarity:0.0001758
#  train_penlog:0.0000000
#  train_molecular_disconnected_validity:100.0000000
#  train_molecular_validity:0.0000000
#  train_symbol_accuracy:0.0000000
#  train_connected_components:21.1666667
#  train_invalid_valency_nodes:0.0000000
# idx_batch=2000
#  train_fgw:0.8000797
#  train_conn_penalty:-0.4156441
#  train_val_penalty:0.0139776
#  train_euler_penalty:0.2843994
#  train_total:0.6828126
#  train_similarity:0.0001801
#  train_penlog:0.0000000
#  train_molecular_disconnected_validity:100.0000000
#  train_molecular_validity:0.0000000
#  train_symbol_accuracy:0.0000000
#  train_connected_components:21.1666667
#  train_invalid_valency_nodes:0.0000000
# idx_batch=2400
#  train_fgw:0.7999259
#  train_conn_penalty:-0.4156486
#  train_val_penalty:0.0139637
#  train_euler_penalty:0.2876880
#  train_total:0.6859291
#  train_similarity:0.0001805
#  train_penlog:0.0000000
#  train_molecular_disconnected_validity:100.0000000
#  train_molecular_validity:0.0000000
#  train_symbol_accuracy:0.0000000
#  train_connected_components:21.1666667
#  train_invalid_valency_nodes:0.0000000
# Epoch 4, train
#  train_fgw:0.7998918
#  train_conn_penalty:-0.4156473
#  train_val_penalty:0.0138847
#  train_euler_penalty:0.2903270
#  train_total:0.6884562
#  train_similarity:0.0001782
#  train_penlog:0.0000000
#  train_molecular_disconnected_validity:100.0000000
#  train_molecular_validity:0.0000000
#  train_symbol_accuracy:0.0000000
#  train_connected_components:21.1666667
#  train_invalid_valency_nodes:0.0000000
# idx_batch=0
#  val_fgw:0.8046030
#  val_conn_penalty:-0.4549225
#  val_val_penalty:0.0143572
#  val_euler_penalty:0.8309750
#  val_total:1.1950127
#  val_similarity:0.0000000
#  val_penlog:0.0000000
#  val_molecular_disconnected_validity:100.0000000
#  val_molecular_validity:0.0000000
#  val_symbol_accuracy:0.0000000
#  val_connected_components:22.0555556
#  val_invalid_valency_nodes:0.0000000
# Epoch 4, val
#  val_fgw:0.8057031
#  val_conn_penalty:-0.4853129
#  val_val_penalty:0.0115640
#  val_euler_penalty:0.8001027
#  val_total:1.1320569
#  val_similarity:0.0000000
#  val_penlog:0.0000000
#  val_molecular_disconnected_validity:100.0000000
#  val_molecular_validity:0.0000000
#  val_symbol_accuracy:0.0000000
#  val_connected_components:22.0555556
#  val_invalid_valency_nodes:0.0000000
# Epoch duration: 4177.300006866455
# Model saved to: mol_opt/output_slot10/model_slot10_4
# Model saved to: mol_opt/output_slot10/model_slot10_decode_4
# Epoch: 5
# idx_batch=0
#  train_fgw:0.8059251
#  train_conn_penalty:-0.2819906
#  train_val_penalty:0.0681003
#  train_euler_penalty:0.6544227
#  train_total:1.2464574
#  train_similarity:0.0000000
#  train_penlog:0.0000000
# Traceback (most recent call last):
#   File "/home/octav/anaconda3/envs/mol_ot/lib/python3.6/multiprocessing/queues.py", line 240, in _feed
#     send_bytes(obj)
#   File "/home/octav/anaconda3/envs/mol_ot/lib/python3.6/multiprocessing/connection.py", line 200, in send_bytes
#     self._send_bytes(m[offset:offset + size])
#   File "/home/octav/anaconda3/envs/mol_ot/lib/python3.6/multiprocessing/connection.py", line 404, in _send_bytes
#     self._send(header + buf)
#   File "/home/octav/anaconda3/envs/mol_ot/lib/python3.6/multiprocessing/connection.py", line 368, in _send
#     n = write(self._handle, buf)
# BrokenPipeError: [Errno 32] Broken pipe
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-b45cff8cb532> in <module>
# ----> 1 molopt = main(args, train_data_loader = train_data_loader, val_data_loader = val_data_loader)
#
# ~/gitrepos/tum-thesis/mol_opt/train_mol_opt.py in main(args, train_data_loader, val_data_loader)
#      98         # run the training procedure
#      99         run_func(molopt, molopt_decoder, optimizer, train_data_loader, "train",
# --> 100                 args, tb_writer, metrics, pen_loss, epoch)
#     101
#     102         # compute the validation loss as well, at the end of the epoch?
#
# ~/gitrepos/tum-thesis/mol_opt/train_mol_opt.py in run_func(mol_opt, mol_opt_decoder, optim, data_loader, data_type, args, tb_writer, metrics, pen_loss, epoch_idx)
#     172         # in your training loop:
#     173         if is_train:
# --> 174             loss.backward()
#     175             optim.step()    # Does the update
#     176
#
# ~/anaconda3/envs/mol_ot/lib/python3.6/site-packages/torch/tensor.py in backward(self, gradient, retain_graph, create_graph)
#     164                 products. Defaults to ``False``.
#     165         """
# --> 166         torch.autograd.backward(self, gradient, retain_graph, create_graph)
#     167
#     168     def register_hook(self, hook):
#
# ~/anaconda3/envs/mol_ot/lib/python3.6/site-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables)
#      97     Variable._execution_engine.run_backward(
#      98         tensors, grad_tensors, retain_graph, create_graph,
# ---> 99         allow_unreachable=True)  # allow_unreachable flag
#     100
#     101
#
# KeyboardInterrupt:

# %%
molopt = main(args, train_data_loader = train_data_loader, val_data_loader = val_data_loader)
# Out:
# Epoch: 2
# /home/octav/gitrepos/tum-thesis/otgnn/models/gromov_modules.py:394: UserWarning: Implicit dimension choice for log_softmax has been deprecated. Change the call to include dim=X as an argument.
#   nce_reg = torch.nn.LogSoftmax()(torch.stack(all_nce_dists))[0]
# idx_batch=0
#  train_fgw:0.6660944
#  train_conn_penalty:-0.2937691
#  train_val_penalty:0.0551586
#  train_euler_penalty:0.2962482
#  train_total:0.7237321
#  train_similarity:0.0024646
#  train_QED:0.4026038
#  train_penlog:1.9305404
# /home/octav/gitrepos/tum-thesis/otgnn/models/gromov_modules.py:394: UserWarning: Implicit dimension choice for log_softmax has been deprecated. Change the call to include dim=X as an argument.
#   nce_reg = torch.nn.LogSoftmax()(torch.stack(all_nce_dists))[0]
# idx_batch=400
#  train_fgw:0.6767198
#  train_conn_penalty:-0.3765132
#  train_val_penalty:0.0798471
#  train_euler_penalty:0.2562876
#  train_total:0.6363414
#  train_similarity:0.0011936
#  train_QED:0.4107739
#  train_penlog:1.5739108
# idx_batch=800
#  train_fgw:0.6706584
#  train_conn_penalty:-0.3762618
#  train_val_penalty:0.0752312
#  train_euler_penalty:0.2419163
#  train_total:0.6115441
#  train_similarity:0.0011363
#  train_QED:0.4122965
#  train_penlog:1.6902422
# idx_batch=1200
#  train_fgw:0.6688505
#  train_conn_penalty:-0.3761556
#  train_val_penalty:0.0750238
#  train_euler_penalty:0.2409354
#  train_total:0.6086542
#  train_similarity:0.0011279
#  train_QED:0.4126643
#  train_penlog:1.6318809
#  train_molecular_disconnected_validity:100.0000000
#  train_molecular_validity:0.0000000
#  train_symbol_accuracy:89.5013123
#  train_connected_components:21.1666667
#  train_invalid_valency_nodes:0.0000000
# idx_batch=1600
#  train_fgw:0.6679104
#  train_conn_penalty:-0.3763058
#  train_val_penalty:0.0751116
#  train_euler_penalty:0.2354048
#  train_total:0.6021210
#  train_similarity:0.0011245
#  train_QED:0.4125602
#  train_penlog:1.6203733
#  train_molecular_disconnected_validity:100.0000000
#  train_molecular_validity:0.0000000
#  train_symbol_accuracy:89.5013123
#  train_connected_components:21.1666667
#  train_invalid_valency_nodes:0.0000000
# idx_batch=2000
#  train_fgw:0.6698198
#  train_conn_penalty:-0.3760327
#  train_val_penalty:0.0759891
#  train_euler_penalty:0.2452485
#  train_total:0.6150246
#  train_similarity:0.0011459
#  train_QED:0.4126969
#  train_penlog:1.5836471
#  train_molecular_disconnected_validity:100.0000000
#  train_molecular_validity:0.0000000
#  train_symbol_accuracy:89.5013123
#  train_connected_components:21.1666667
#  train_invalid_valency_nodes:0.0000000
# idx_batch=2400
#  train_fgw:0.6680303
#  train_conn_penalty:-0.3756744
#  train_val_penalty:0.0748842
#  train_euler_penalty:0.2385252
#  train_total:0.6057652
#  train_similarity:0.0011500
#  train_QED:0.4131820
#  train_penlog:1.6106410
#  train_molecular_disconnected_validity:100.0000000
#  train_molecular_validity:0.0000000
#  train_symbol_accuracy:89.5013123
#  train_connected_components:21.1666667
#  train_invalid_valency_nodes:0.0000000
# Epoch 2, train
#  train_fgw:0.6679459
#  train_conn_penalty:-0.3757724
#  train_val_penalty:0.0748514
#  train_euler_penalty:0.2391761
#  train_total:0.6062010
#  train_similarity:0.0011490
#  train_QED:0.4132032
#  train_penlog:1.6143758
#  train_molecular_disconnected_validity:100.0000000
#  train_molecular_validity:0.0000000
#  train_symbol_accuracy:89.5013123
#  train_connected_components:21.1666667
#  train_invalid_valency_nodes:0.0000000
# idx_batch=0
#  val_fgw:0.6808448
#  val_conn_penalty:-0.3849382
#  val_val_penalty:0.0741106
#  val_euler_penalty:0.7575316
#  val_total:1.1275490
#  val_similarity:0.0008681
#  val_QED:0.3906766
#  val_penlog:2.0851285
#  val_molecular_disconnected_validity:100.0000000
#  val_molecular_validity:0.0000000
#  val_symbol_accuracy:86.5239295
#  val_connected_components:22.0555556
#  val_invalid_valency_nodes:0.0000000
# Epoch 2, val
#  val_fgw:0.6607174
#  val_conn_penalty:-0.4168579
#  val_val_penalty:0.1019932
#  val_euler_penalty:0.6276133
#  val_total:0.9734660
#  val_similarity:0.0015407
#  val_QED:0.3895571
#  val_penlog:2.1705877
#  val_molecular_disconnected_validity:100.0000000
#  val_molecular_validity:0.0000000
#  val_symbol_accuracy:86.5239295
#  val_connected_components:22.0555556
#  val_invalid_valency_nodes:0.0000000
# Epoch duration: 5009.661825180054
# Model saved to: mol_opt/output_slot10/model_slot10_2
# Model saved to: mol_opt/output_slot10/model_slot10_decode_2
# Epoch: 3
# idx_batch=0
#  train_fgw:0.6702409
#  train_conn_penalty:-0.2820849
#  train_val_penalty:0.1018645
#  train_euler_penalty:0.4200957
#  train_total:0.9101162
#  train_similarity:0.0029520
#  train_QED:0.4411133
#  train_penlog:1.7819901
# idx_batch=400
#  train_fgw:0.6620609
#  train_conn_penalty:-0.3895746
#  train_val_penalty:0.0873532
#  train_euler_penalty:0.2709900
#  train_total:0.6308295
#  train_similarity:0.0011959
#  train_QED:0.4094588
#  train_penlog:0.8816529
# idx_batch=800
#  train_fgw:0.6604015
#  train_conn_penalty:-0.3901614
#  train_val_penalty:0.0858213
#  train_euler_penalty:0.2600197
#  train_total:0.6160812
#  train_similarity:0.0011201
#  train_QED:0.4100350
#  train_penlog:1.1540907
# idx_batch=1200
#  train_fgw:0.6603968
#  train_conn_penalty:-0.3899861
#  train_val_penalty:0.0873222
#  train_euler_penalty:0.2515800
#  train_total:0.6093129
#  train_similarity:0.0011013
#  train_QED:0.4098605
#  train_penlog:1.1608715
#  train_molecular_disconnected_validity:100.0000000
#  train_molecular_validity:0.0000000
#  train_symbol_accuracy:87.5328084
#  train_connected_components:21.1666667
#  train_invalid_valency_nodes:0.0000000
# idx_batch=1600
#  train_fgw:0.6622654
#  train_conn_penalty:-0.3901317
#  train_val_penalty:0.0861286
#  train_euler_penalty:0.2577021
#  train_total:0.6159644
#  train_similarity:0.0011050
#  train_QED:0.4101301
#  train_penlog:1.1811023
#  train_molecular_disconnected_validity:100.0000000
#  train_molecular_validity:0.0000000
#  train_symbol_accuracy:87.5328084
#  train_connected_components:21.1666667
#  train_invalid_valency_nodes:0.0000000
# idx_batch=2000
#  train_fgw:0.6627115
#  train_conn_penalty:-0.3899535
#  train_val_penalty:0.0860630
#  train_euler_penalty:0.2584667
#  train_total:0.6172877
#  train_similarity:0.0011295
#  train_QED:0.4107209
#  train_penlog:1.2271162
#  train_molecular_disconnected_validity:100.0000000
#  train_molecular_validity:0.0000000
#  train_symbol_accuracy:87.5328084
#  train_connected_components:21.1666667
#  train_invalid_valency_nodes:0.0000000
# idx_batch=2400
#  train_fgw:0.6610245
#  train_conn_penalty:-0.3901624
#  train_val_penalty:0.0854286
#  train_euler_penalty:0.2550055
#  train_total:0.6112962
#  train_similarity:0.0011308
#  train_QED:0.4107294
#  train_penlog:1.2659505
#  train_molecular_disconnected_validity:100.0000000
#  train_molecular_validity:0.0000000
#  train_symbol_accuracy:87.5328084
#  train_connected_components:21.1666667
#  train_invalid_valency_nodes:0.0000000
# Epoch 3, train
#  train_fgw:0.6608716
#  train_conn_penalty:-0.3901862
#  train_val_penalty:0.0854550
#  train_euler_penalty:0.2549738
#  train_total:0.6111142
#  train_similarity:0.0011300
#  train_QED:0.4107046
#  train_penlog:1.2747168
#  train_molecular_disconnected_validity:100.0000000
#  train_molecular_validity:0.0000000
#  train_symbol_accuracy:87.5328084
#  train_connected_components:21.1666667
#  train_invalid_valency_nodes:0.0000000
# idx_batch=0
#  val_fgw:0.6693861
#  val_conn_penalty:-0.4544285
#  val_val_penalty:0.0803639
#  val_euler_penalty:0.5398624
#  val_total:0.8351839
#  val_similarity:0.0008961
#  val_QED:0.3997978
#  val_penlog:2.1714259
#  val_molecular_disconnected_validity:100.0000000
#  val_molecular_validity:0.0000000
#  val_symbol_accuracy:85.5163728
#  val_connected_components:22.0555556
#  val_invalid_valency_nodes:0.0000000
# Epoch 3, val
#  val_fgw:0.6520747
#  val_conn_penalty:-0.4830488
#  val_val_penalty:0.1855908
#  val_euler_penalty:0.8901991
#  val_total:1.2448158
#  val_similarity:0.0015226
#  val_QED:0.3711489
#  val_penlog:-2.2386908
#  val_molecular_disconnected_validity:100.0000000
#  val_molecular_validity:0.0000000
#  val_symbol_accuracy:85.5163728
#  val_connected_components:22.0555556
#  val_invalid_valency_nodes:0.0000000
# Epoch duration: 6007.431439399719
# Model saved to: mol_opt/output_slot10/model_slot10_3
# Model saved to: mol_opt/output_slot10/model_slot10_decode_3
# Epoch: 4
# idx_batch=0
#  train_fgw:0.6657685
#  train_conn_penalty:-0.4258103
#  train_val_penalty:0.1842999
#  train_euler_penalty:0.1427733
#  train_total:0.5670313
#  train_similarity:0.0024888
#  train_QED:0.4324166
#  train_penlog:-0.9722750
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-b45cff8cb532> in <module>
# ----> 1 molopt = main(args, train_data_loader = train_data_loader, val_data_loader = val_data_loader)
#
# ~/gitrepos/tum-thesis/mol_opt/train_mol_opt.py in main(args, train_data_loader, val_data_loader)
#      98         # run the training procedure
#      99         run_func(molopt, molopt_decoder, optimizer, train_data_loader, "train",
# --> 100                 args, tb_writer, metrics, pen_loss, epoch)
#     101
#     102         # compute the validation loss as well, at the end of the epoch?
#
# ~/gitrepos/tum-thesis/mol_opt/train_mol_opt.py in run_func(mol_opt, mol_opt_decoder, optim, data_loader, data_type, args, tb_writer, metrics, pen_loss, epoch_idx)
#     166         # add metric stats
#     167         # we might want to do this only for the validation set
# --> 168         measure_results = measure_task(X, pred_pack[0])
#     169         for key in measure_results:
#     170             stats_tracker.add_stat("{}_{}".format(data_type, key), measure_results[key], n_data)
#
# ~/gitrepos/tum-thesis/mol_opt/task_metrics.py in measure_task(X, pred_pack)
#      35
#      36         res["similarity"] += props.similarity(pmol, Chem.MolToSmiles(X.rd_mols[mol_idx]))
# ---> 37         # res["QED"] += props.qed(pmol)
#      38         res["penlog"] += props.penalized_logp(pmol)
#      39
#
# ~/gitrepos/tum-thesis/iclr19-graph2graph/props/properties.py in qed(s)
#      30     mol = Chem.MolFromSmiles(s)
#      31     if mol is None: return 0.0
# ---> 32     return QED.qed(mol)
#      33
#      34 # Modified from https://github.com/bowenliu16/rl_graph_generation
#
# ~/anaconda3/envs/mol_ot/lib/python3.6/site-packages/rdkit/Chem/QED.py in qed(mol, w, qedProperties)
#     283   """
#     284   if qedProperties is None:
# --> 285       qedProperties = properties(mol)
#     286   d = [ads(pi, adsParameters[name]) for name, pi in qedProperties._asdict().items()]
#     287   t = sum(wi * math.log(di) for wi, di in zip(w, d))
#
# ~/anaconda3/envs/mol_ot/lib/python3.6/site-packages/rdkit/Chem/QED.py in properties(mol)
#     246   if mol is None:
#     247     raise ValueError('You need to provide a mol argument.')
# --> 248   mol = Chem.RemoveHs(mol)
#     249   qedProperties = QEDproperties(
#     250     MW=rdmd._CalcMolWt(mol),
#
# ValueError: Sanitization error: Explicit valence for atom # 14 C, 8, is greater than permitted
